# %%
# %load_ext dotenv
# %dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in Dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss Dask vs. Pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance, and the data, along with its description, is available via [Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset).
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# <div>
# <img src="./images/02_medallion_architecture.png" height=300>
# </div>
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class to control the process of obtaining and transforming our data.
#
# <div>
# <img src="./images/02_target_pipeline_manager.png" height=250>
# </div>

# %% [markdown]
# # Download Data
#
# Download the [Stock Market Dataset from Kaggle](https://www.kaggle.com/datasets/jacksoncrow/stock-market-dataset). Note that you may be required to register for a free account. Alternatively, download the file from [this location](https://drive.google.com/drive/folders/1AA4gapDLpI194TGce1bY25sd91Km-tU3?usp=drive_link).
#
# + Extract stock prices (not ETFs) into the directory: `./05_src/data/prices_csv/`.
# + To be clear, your folder structure should include the path `05_src/data/prices_csv/stocks`.

# %% [markdown]
# The command `%run update_path.py` runs a local script that adds the repository's `../../05_src/` directory to the notebook's kernel path. This way, we can use our modules within the notebook.

# %%
# %run update_path.py

# %% [markdown]
# To load the historical price data for stocks and ETFs, use the code below. Notice the following:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager. Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by [Python's documentation](https://docs.python.org/3/howto/logging.html#logging-advanced-tutorial).

# %%
from glob import glob
import os
import pandas as pd
import random

from utils.logger import get_logger
_logs = get_logger(__name__)

# %% [markdown]
# + The [`glob` module](https://docs.python.org/3/library/glob.html) is used for finding path names that match specified patterns using Unix shell-style rules.
#
# + Notice that the module `glob` contains a function called `glob`; therefore, we used `from glob import glob` above.
#
# + The path in which we are searching for our csv files is produced by joining two strings:
#
#
#
#     - The value of the environment variable 'SRC_DIR' that we obtain with `os.getenv('SRC_DIR')` (this variable points to ./05_src).
#
#     - Another string given by "data/prices_csv/stocks/*.csv".
#
#     - Both strings are combined into an OS-consistent path using `os.path.join(...)`.
#
# + After we know the location of all our files, we sample a subset of them.

# %%
stock_files = glob(os.path.join(os.getenv('SRC_DIR'), "data/prices_csv/stocks/*.csv"))
_logs.info(f'Found {len(stock_files)} stock price files.')

random.seed(42)
n_sample = 60
stock_files = random.sample(stock_files, n_sample)
_logs.info(f'Sampled {n_sample} stock price files for processing. The files are: {stock_files   }')
# Out:
# 2026-06-07 10:29:40,932, 3619788285.py, 2, INFO, Found 5884 stock price files.
csv', '../../05_src/data/prices_csv/stocks\\LEVL.csv', '../../05_src/data/prices_csv/stocks\\BGS.csv', '../../05_src/data/prices_csv/stocks\\RIV.csv', '../../05_src/data/prices_csv/stocks\\GURE.csv', '../../05_src/data/prices_csv/stocks\\TEF.csv', '../../05_src/data/prices_csv/stocks\\SYNH.csv', '../../05_src/data/prices_csv/stocks\\KEY.csv']

# %% [markdown]
# We load the sampled files into dataframes and concatenate them:
#
# + Start with an empty list.
# + Read each file into a dataframe and [`append()` it to the list](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists). Notice that `append()` is an in-place operation (it does not return a list, it modifies the list in place).
# + Finally, we concatenate all dataframes along the vertical axis (`axis=0`) using [`pd.concat()`](https://pandas.pydata.org/docs/user_guide/merging.html#concat).
# + Notice that we do not concatenate each time that we load a dataframe. According to [Panda's documentation](https://pandas.pydata.org/docs/user_guide/merging.html#concat):
#
# > "`concat()` makes a full copy of the data, and iteratively reusing `concat()` can create unnecessary copies. Collect all DataFrame or Series objects in a list before using `concat()`."

# %%
dt_list = []
for s_file in stock_files:
    _logs.info(f"Reading file: {s_file}")
    dt = pd.read_csv(s_file).assign(
        source = os.path.basename(s_file),
        ticker = os.path.basename(s_file).replace('.csv', ''),
        Date = lambda x: pd.to_datetime(x['Date'])
    )
    dt_list.append(dt)
stock_prices = pd.concat(dt_list, axis = 0, ignore_index = True)
# Out:
# 2026-06-07 10:29:48,812, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TNC.csv
# 2026-06-07 10:29:48,880, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CBB.csv
# 2026-06-07 10:29:48,917, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ALDX.csv
# 2026-06-07 10:29:48,937, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLADD.csv
# 2026-06-07 10:29:48,957, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\FIXX.csv
# 2026-06-07 10:29:48,986, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ETJ.csv
# 2026-06-07 10:29:49,036, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CMCTP.csv
# 2026-06-07 10:29:49,069, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BWG.csv
# 2026-06-07 10:29:49,101, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\VIAC.csv
# 2026-06-07 10:29:49,144, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\REI.csv
# 2026-06-07 10:29:49,174, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BLPH.csv
# 2026-06-07 10:29:49,200, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SMG.csv
# 2026-06-07 10:29:49,226, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MOH.csv
# 2026-06-07 10:29:49,253, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AMH.csv
# 2026-06-07 10:29:49,280, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AMAL.csv
# 2026-06-07 10:29:49,306, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BPYPN.csv
# 2026-06-07 10:29:49,337, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ERH.csv
# 2026-06-07 10:29:49,387, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\FAMI.csv
# 2026-06-07 10:29:49,409, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\PFG.csv
# 2026-06-07 10:29:49,439, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SPXC.csv
# 2026-06-07 10:29:49,483, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ALL.csv
# 2026-06-07 10:29:49,525, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RTTR.csv
# 2026-06-07 10:29:49,553, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\EARN.csv
# 2026-06-07 10:29:49,582, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ZIXI.csv
# 2026-06-07 10:29:49,618, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TSN.csv
# 2026-06-07 10:29:49,657, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\WST.csv
# 2026-06-07 10:29:49,702, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\REG.csv
# 2026-06-07 10:29:49,743, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MNK.csv
# 2026-06-07 10:29:49,772, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ESGR.csv
# 2026-06-07 10:29:49,818, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\NGD.csv
# 2026-06-07 10:29:49,846, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SLRX.csv
# 2026-06-07 10:29:49,868, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLW.csv
# 2026-06-07 10:29:49,905, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ACN.csv
# 2026-06-07 10:29:49,934, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CSSE.csv
# 2026-06-07 10:29:49,951, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\WORK.csv
# 2026-06-07 10:29:49,969, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\MOS.csv
# 2026-06-07 10:29:49,991, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\IPWR.csv
# 2026-06-07 10:29:50,018, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GLUU.csv
# 2026-06-07 10:29:50,056, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CRMT.csv
# 2026-06-07 10:29:50,086, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\EOLS.csv
# 2026-06-07 10:29:50,104, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\INSU.csv
# 2026-06-07 10:29:50,124, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BWEN.csv
# 2026-06-07 10:29:50,157, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BPMX.csv
# 2026-06-07 10:29:50,230, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\LH.csv
# 2026-06-07 10:29:50,266, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BRQS.csv
# 2026-06-07 10:29:50,288, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KALU.csv
# 2026-06-07 10:29:50,310, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\ITCB.csv
# 2026-06-07 10:29:50,338, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SRE.csv
# 2026-06-07 10:29:50,364, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GAZ.csv
# 2026-06-07 10:29:50,385, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\AQMS.csv
# 2026-06-07 10:29:50,406, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\NPK.csv
# 2026-06-07 10:29:50,440, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\QRHC.csv
# 2026-06-07 10:29:50,470, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\CGEN.csv
# 2026-06-07 10:29:50,498, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\LEVL.csv
# 2026-06-07 10:29:50,515, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\BGS.csv
# 2026-06-07 10:29:50,541, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\RIV.csv
# 2026-06-07 10:29:50,560, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\GURE.csv
# 2026-06-07 10:29:50,586, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\TEF.csv
# 2026-06-07 10:29:50,632, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\SYNH.csv
# 2026-06-07 10:29:50,661, 2577063914.py, 3, INFO, Reading file: ../../05_src/data/prices_csv/stocks\KEY.csv

# %% [markdown]
# Verify the structure of the `stock_prices` data using the [`info()` dataframe method](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html):

# %%
stock_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239659 entries, 0 to 239658
# Data columns (total 9 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       239659 non-null  datetime64[ns]
#  1   Open       239656 non-null  float64
#  2   High       239656 non-null  float64
#  3   Low        239656 non-null  float64
#  4   Close      239656 non-null  float64
#  5   Adj Close  239656 non-null  float64
#  6   Volume     239656 non-null  float64
#  7   source     239659 non-null  object
#  8   ticker     239659 non-null  object
# dtypes: datetime64[ns](1), float64(6), object(2)
# memory usage: 16.5+ MB

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. Good references for this type of data manipulation are:
#
# + [Panda's Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data).
# + [Panda's Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
select_tickers = stock_prices['ticker'].unique().tolist()
select_tickers
# Out:
# ['TNC',
#  'CBB',
#  'ALDX',
#  'GLADD',
#  'FIXX',
#  'ETJ',
#  'CMCTP',
#  'BWG',
#  'VIAC',
#  'REI',
#  'BLPH',
#  'SMG',
#  'MOH',
#  'AMH',
#  'AMAL',
#  'BPYPN',
#  'ERH',
#  'FAMI',
#  'PFG',
#  'SPXC',
#  'ALL',
#  'RTTR',
#  'EARN',
#  'ZIXI',
#  'TSN',
#  'WST',
#  'REG',
#  'MNK',
#  'ESGR',
#  'NGD',
#  'SLRX',
#  'GLW',
#  'ACN',
#  'CSSE',
#  'WORK',
#  'MOS',
#  'IPWR',
#  'GLUU',
#  'CRMT',
#  'EOLS',
#  'INSU',
#  'BWEN',
#  'BPMX',
#  'LH',
#  'BRQS',
#  'KALU',
#  'ITCB',
#  'SRE',
#  'GAZ',
#  'AQMS',
#  'NPK',
#  'QRHC',
#  'CGEN',
#  'LEVL',
#  'BGS',
#  'RIV',
#  'GURE',
#  'TEF',
#  'SYNH',
#  'KEY']

# %% [markdown]
# # Storing Data in CSV
#
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parquet, by measuring their performance:
#
#     - Time to save: We will measure time by using the `time` library.
#     - Space required on drive: We will use the custom function below.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %% [markdown]
# Load the specification of a temporary directory from the environment  and create a subdirectory in it called "csv":
#
# + Use `os.getenv("TEMP_DATA")` to obtain the desired location of the temporary folder from an environment variable.
# + If the subdirectory exists, delete it using `shutil.rmtree()`; the flag `ignore_errors=True` helps us in case the subdirectory does not exist (for instance, in the first run).
# + Create a directory with path given by `csv_dir` using `os.makedirs()`; the flag `exist_ok=True` indicates that if the directory already exists, then the function will do nothing.
# + Finally, create the stock price file location, `stock_csv`, which will be used to create the csv file.

# %%
import shutil

temp = os.getenv("TEMP_DATA")
csv_dir = os.path.join(temp, "csv")

shutil.rmtree(csv_dir, ignore_errors=True)
os.makedirs(csv_dir, exist_ok=True)
stock_csv = os.path.join(csv_dir, "stock_px.csv")

# %% [markdown]
# Save the concatenated dataframe to a CSV file. We measure the time elapsed by storing the start and end times, then we calculate their difference in seconds.

# %%
import time

start = time.time()
stock_prices.to_csv(stock_csv, index = False)
end = time.time()

_logs.info(f'Writing data ({stock_prices.shape}) to csv took {end - start} seconds.')
_logs.info(f'CSV file size { os.path.getsize(stock_csv)*1e-6 } MB')
# Out:
# 2026-06-07 10:31:40,488, 807204384.py, 7, INFO, Writing data ((239659, 9)) to csv took 2.206763982772827 seconds.
# 2026-06-07 10:31:40,488, 807204384.py, 8, INFO, CSV file size 26.618403999999998 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Notes on Dask
#
# We could use Pandas to save the data directly into Parquet files. However, we will use a different approach by applying the [Dask framework](https://www.dask.org/). Dask provides functionality for working with datasets that do not fit in memory and parallelization to speed up computation. A few notes on Dask and Pandas:
#
# - Pandas, Parquet, and Arrow:
#
#     + We can work with large datasets and Parquet files in Pandas, but we will generally be limited by the amount of data that can fit in our computer's memory.
#     + Pandas can write Parquet files using a PyArrow backend. In fact, recent versions of Pandas support PyArrow data types, and future versions will require a PyArrow backend.
#     + The PyArrow library is an interface between Python and the Apache Arrow project. In particular, the [Parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are Apache projects.
#
# - Dask
#
#     + Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on Pandas-like dataframes.
#     + Dask is also relatively easy to use as it mimics Pandas' API.
#     + Dask allows us to work with larger datasets than Pandas. In a sense, it is an intermediate step between Pandas and big-data frameworks like Spark (or Databricks).
#     + If you are familiar with Pandas, a good introduction is [10 Minutes to Dask](https://docs.dask.org/en/stable/10-minutes-to-dask.html).

# %%
import dask.dataframe as dd

parquet_dir = os.path.join(temp, "parquet")
shutil.rmtree(parquet_dir, ignore_errors=True)
os.makedirs(parquet_dir, exist_ok=True)

# %%
px_dd = dd.from_pandas(stock_prices, npartitions = len(select_tickers))

start = time.time()
px_dd.to_parquet(parquet_dir, engine = "pyarrow")
end = time.time()

_logs.info(f'Writing dd ({stock_prices.shape}) to parquet took {end - start} seconds.')
_logs.info(f'Parquet file size { get_dir_size(parquet_dir)*1e-6 } MB')
# Out:
# 2026-06-07 10:31:54,761, 817812245.py, 7, INFO, Writing dd ((239659, 9)) to parquet took 0.6168303489685059 seconds.
# 2026-06-07 10:31:54,761, 817812245.py, 8, INFO, Parquet file size 9.721594 MB

# %% [markdown]
# ### Pandas, Dask, and Parquet
#
# The distinction of Pandas Dataframes, Dask Dataframes, and Parquet files is important:
#
# + Pandas dataframes combine the functionality of [NumPy](https://numpy.org/) (efficient vector operations, especially vector algebra) with a concise data manipulation framework that allows us to create columns of different data types (NumPy only allows single-type matrices), database-like operations (such as filtering rows, subsetting columns, and joining different dataframes).
# + Dask dataframes extend the functionality of Pandas dataframes beyond the confines of available memory and implement parallelized operations, among other benefits.
# + Parquet files are a file format. Parquet files can be created by Pandas and Dask, but Dask offers a superior interface. Parquet files are immutable: once written, they cannot be modified.
# + Parquet and Dask are not the same: Parquet is a file format that can be accessed by many applications and programming languages (Python, R, Power BI, etc.), while Dask is a Python package for working with large datasets using distributed computation.

# %% [markdown]
# ### Dask is Powerful, but not Infallible
#
# It is tempting to think of Dask as a super-Pandas, but each package has its advantages and disadvantages.
#
# + Dask is not good at everything (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
# + A useful and somewhat idiosyncratic comparison of various data manipulation frameworks is shown below (from [DataFrames at Scale Comparison: TPC-H](https://docs.coiled.io/blog/tpch.html#when-to-use-duckdb-vs-polars-vs-dask-vs-spark))
#
# Concept              | Spark | Dask | DuckDB | Polars
# ---------------------|-------|------|--------|--------
# Fast Locally         | ❌    | 🤔  | ✅     | ✅
# Fast on Cloud (1 TB) | ✅    | ✅  | ✅     | ❌
# Fast on Cloud (10 TB)| ❌    | ✅  | ✅     | ❌
# Scales Out           | ✅    | ✅  | ❌     | ❌
# SQL                  | ✅    | 🤔  | ✅     | 🤔
# More than SQL        | ✅    | ✅  | ❌     | ✅
# Sensible Defaults    | ❌    | ✅  | ✅     | ✅
#
#
# ### Dask Best Practices
#
# Parallelism brings extra complexity and overhead. Here are a few ideas to help you decide when to use Dask (from [Dask's Best Practices](https://docs.dask.org/en/stable/best-practices.html)):
#
# #### Small is Better
#
# + Start small: if possible, use Pandas. Also, try to reduce your data using aggregation, then use Pandas.
# + More generally, NumPy, Pandas, and Scikit-Learn may have faster functions for what you need. Consult the relevant documentation, experiment, and/or consult with a colleague or expert.
#
# #### Index with Care
#
# + Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
# + Minimize full-data shuffling as much as possible: indexing is an expensive operation.
#
# ### Consider the Cost of Joins
#
# + Consider cases such as small-to-large joins, where the small dataframe fits in memory, but the large one does not. The small dataframe can be Pandas, while the larger one is a Dask dataframe.
# + Some joins are more expensive than others.
#
#     * Not expensive:
#
#         - Join a Dask DataFrame with a Pandas DataFrame.
#         - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#         - Join Dask DataFrames along their indexes.
#
#     * Expensive:
#
#         - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How Do We Store Prices?
#
# + We can store our data as a single blob.
#
#   - This can be difficult to maintain, especially because parquet files are immutable.
#   - Using a single file, we would need to recreate the complete file any time that we update it.
#
# + An alternative strategy is to organize data files by ticker and date:
#
#   - We can create one file per ticker and month (or any other suitable frequency).
#   - Under this approach, we would only need to recreate the latest month's file at any update.

# %%
# Clean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
stock_prices.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'source',
#        'ticker'],
#       dtype='object')

# %%
for ticker in stock_prices['ticker'].unique():
    # Filter data for ticker
    # Notice that these are Pandas dataframes
    _logs.info(f'Processing ticker: {ticker}')
    ticker_dt = stock_prices[stock_prices['ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        _logs.info(f'Processing year {yr} for ticker {ticker}.')
        # Filter data for year and convert to Dask dataframe
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        
        # Define path and create directories if not exist
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        _logs.info(f'Writing data to path: {yr_path}')

        # Write to Parquet
        yr_dd.to_parquet(yr_path, engine = "pyarrow")
# Out:
# 2026-06-07 10:32:07,144, 2113979629.py, 4, INFO, Processing ticker: TNC
# 2026-06-07 10:32:07,175, 2113979629.py, 8, INFO, Processing year 1973 for ticker TNC.
# 2026-06-07 10:32:07,191, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1973
# 2026-06-07 10:32:07,212, 2113979629.py, 8, INFO, Processing year 1974 for ticker TNC.
# 2026-06-07 10:32:07,212, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1974
# 2026-06-07 10:32:07,248, 2113979629.py, 8, INFO, Processing year 1975 for ticker TNC.
# 2026-06-07 10:32:07,252, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1975
# 2026-06-07 10:32:07,279, 2113979629.py, 8, INFO, Processing year 1976 for ticker TNC.
# 2026-06-07 10:32:07,279, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_1976
# 2026-06-07 10:32:07,314, 2113979629.py, 8, INFO, Processing year 1977 for ticker TNC.
# 2026-06-07 10:32:07,319, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TNC\TNC_
 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2013
# 2026-06-07 10:32:11,027, 2113979629.py, 8, INFO, Processing year 2014 for ticker ETJ.
# 2026-06-07 10:32:11,044, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2014
# 2026-06-07 10:32:11,068, 2113979629.py, 8, INFO, Processing year 2015 for ticker ETJ.
# 2026-06-07 10:32:11,073, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2015
# 2026-06-07 10:32:11,084, 2113979629.py, 8, INFO, Processing year 2016 for ticker ETJ.
# 2026-06-07 10:32:11,100, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2016
# 2026-06-07 10:32:11,123, 2113979629.py, 8, INFO, Processing year 2017 for ticker ETJ.
# 2026-06-07 10:32:11,133, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2017
# 2026-06-07 10:32:11,164, 2113979629.py, 8, INFO, Processing year 2018 for ticker ETJ.
# 2026-06-07 10:32:11,167, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2018
# 2026-06-07 10:32:11,197, 2113979629.py, 8, INFO, Processing year 2019 for ticker ETJ.
# 2026-06-07 10:32:11,203, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2019
# 2026-06-07 10:32:11,236, 2113979629.py, 8, INFO, Processing year 2020 for ticker ETJ.
# 2026-06-07 10:32:11,238, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/ETJ\ETJ_2020
# 2026-06-07 10:32:11,272, 2113979629.py, 4, INFO, Processing ticker: CMCTP
# 2026-06-07 10:32:11,291, 2113979629.py, 8, INFO, Processing year 2018 for ticker CMCTP.
# 2026-06-07 10:32:11,301, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2018
# 2026-06-07 10:32:11,331, 2113979629.py, 8, INFO, Processing year 2019 for ticker CMCTP.
# 2026-06-07 10:32:11,337, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2019
# 2026-06-07 10:32:11,360, 2113979629.py, 8, INFO, Processing year 2020 for ticker CMCTP.
# 2026-06-07 10:32:11,367, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/CMCTP\CMCTP_2020
# 2026-06-07 10:32:11,387, 2113979629.py, 4, INFO, Processing ticker: BWG
# 2026-06-07 10:32:11,401, 2113979629.py, 8, INFO, Processing year 2012 for ticker BWG.
# 2026-06-07 10:32:11,408, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2012
# 2026-06-07 10:32:11,431, 2113979629.py, 8, INFO, Processing year 2013 for ticker BWG.
# 2026-06-07 10:32:11,435, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2013
# 2026-06-07 10:32:11,450, 2113979629.py, 8, INFO, Processing year 2014 for ticker BWG.
# 2026-06-07 10:32:11,465, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2014
# 2026-06-07 10:32:11,478, 2113979629.py, 8, INFO, Processing year 2015 for ticker BWG.
# 2026-06-07 10:32:11,478, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2015
# 2026-06-07 10:32:11,508, 2113979629.py, 8, INFO, Processing year 2016 for ticker BWG.
# 2026-06-07 10:32:11,514, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2016
# 2026-06-07 10:32:11,534, 2113979629.py, 8, INFO, Processing year 2017 for ticker BWG.
# 2026-06-07 10:32:11,534, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2017
# 2026-06-07 10:32:11,561, 2113979629.py, 8, INFO, Processing year 2018 for ticker BWG.
# 2026-06-07 10:32:11,561, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2018
# 2026-06-07 10:32:11,583, 2113979629.py, 8, INFO, Processing year 2019 for ticker BWG.
# 2026-06-07 10:32:11,597, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2019
# 2026-06-07 10:32:11,620, 2113979629.py, 8, INFO, Processing year 2020 for ticker BWG.
# 2026-06-07 10:32:11,632, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/BWG\BWG_2020
# 2026-06-07 10:32:11,660, 2113979629.py, 4, INFO, Processing ticker: VIAC
# 2026-06-07 10:32:11,677, 2113979629.py, 8, INFO, Processing year 2005 for ticker VIAC.
# 2026-06-07 10:32:11,678, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2005
# 2026-06-07 10:32:11,701, 2113979629.py, 8, INFO, Processing year 2006 for ticker VIAC.
# 2026-06-07 10:32:11,713, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2006
# 2026-06-07 10:32:11,735, 2113979629.py, 8, INFO, Processing year 2007 for ticker VIAC.
# 2026-06-07 10:32:11,738, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2007
# 2026-06-07 10:32:11,765, 2113979629.py, 8, INFO, Processing year 2008 for ticker VIAC.
# 2026-06-07 10:32:11,770, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2008
# 2026-06-07 10:32:11,780, 2113979629.py, 8, INFO, Processing year 2009 for ticker VIAC.
# 2026-06-07 10:32:11,795, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2009
# 2026-06-07 10:32:11,817, 2113979629.py, 8, INFO, Processing year 2010 for ticker VIAC.
# 2026-06-07 10:32:11,823, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2010
# 2026-06-07 10:32:11,850, 2113979629.py, 8, INFO, Processing year 2011 for ticker VIAC.
# 2026-06-07 10:32:11,856, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2011
# 2026-06-07 10:32:11,884, 2113979629.py, 8, INFO, Processing year 2012 for ticker VIAC.
# 2026-06-07 10:32:11,891, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2012
# 2026-06-07 10:32:11,915, 2113979629.py, 8, INFO, Processing year 2013 for ticker VIAC.
# 2026-06-07 10:32:11,921, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2013
# 2026-06-07 10:32:11,950, 2113979629.py, 8, INFO, Processing year 2014 for ticker VIAC.
# 2026-06-07 10:32:11,950, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2014
# 2026-06-07 10:32:11,983, 2113979629.py, 8, INFO, Processing year 2015 for ticker VIAC.
# 2026-06-07 10:32:11,983, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2015
# 2026-06-07 10:32:12,019, 2113979629.py, 8, INFO, Processing year 2016 for ticker VIAC.
# 2026-06-07 10:32:12,036, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2016
# 2026-06-07 10:32:12,068, 2113979629.py, 8, INFO, Processing year 2017 for ticker VIAC.
# 2026-06-07 10:32:12,075, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2017
# 2026-06-07 10:32:12,114, 2113979629.py, 8, INFO, Processing year 2018 for ticker VIAC.
# 2026-06-07 10:32:12,117, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2018
# 2026-06-07 10:32:12,153, 2113979629.py, 8, INFO, Processing year 2019 for ticker VIAC.
# 2026-06-07 10:32:12,158, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2019
# 2026-06-07 10:32:12,184, 2113979629.py, 8, INFO, Processing year 2020 for ticker VIAC.
# 2026-06-07 10:32:12,184, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/VIAC\VIAC_2020
# 2026-06-07 10:32:12,200, 2113979629.py, 4, INFO, Processing ticker: REI
# 2026-06-07 10:32:12,217, 2113979629.py, 8, INFO, Processing year 2007 for ticker REI.
# 2026-06-07 10:32:12,231, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2007
# 2026-06-07 10:32:12,249, 2113979629.py, 8, INFO, Processing year 2008 for ticker REI.
# 2026-06-07 10:32:12,256, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2008
# 2026-06-07 10:32:12,274, 2113979629.py, 8, INFO, Processing year 2009 for ticker REI.
# 2026-06-07 10:32:12,280, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2009
# 2026-06-07 10:32:12,298, 2113979629.py, 8, INFO, Processing year 2010 for ticker REI.
# 2026-06-07 10:32:12,301, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_2010
# 2026-06-07 10:32:12,317, 2113979629.py, 8, INFO, Processing year 2011 for ticker REI.
# 2026-06-07 10:32:12,330, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/REI\REI_
 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1997
# 2026-06-07 10:32:12,997, 2113979629.py, 8, INFO, Processing year 1998 for ticker SMG.
# 2026-06-07 10:32:13,003, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1998
# 2026-06-07 10:32:13,019, 2113979629.py, 8, INFO, Processing year 1999 for ticker SMG.
# 2026-06-07 10:32:13,026, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_1999
# 2026-06-07 10:32:13,045, 2113979629.py, 8, INFO, Processing year 2000 for ticker SMG.
# 2026-06-07 10:32:13,050, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2000
# 2026-06-07 10:32:13,067, 2113979629.py, 8, INFO, Processing year 2001 for ticker SMG.
# 2026-06-07 10:32:13,082, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2001
# 2026-06-07 10:32:13,101, 2113979629.py, 8, INFO, Processing year 2002 for ticker SMG.
# 2026-06-07 10:32:13,116, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2002
# 2026-06-07 10:32:13,140, 2113979629.py, 8, INFO, Processing year 2003 for ticker SMG.
# 2026-06-07 10:32:13,144, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2003
# 2026-06-07 10:32:13,163, 2113979629.py, 8, INFO, Processing year 2004 for ticker SMG.
# 2026-06-07 10:32:13,176, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2004
# 2026-06-07 10:32:13,192, 2113979629.py, 8, INFO, Processing year 2005 for ticker SMG.
# 2026-06-07 10:32:13,205, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2005
# 2026-06-07 10:32:13,223, 2113979629.py, 8, INFO, Processing year 2006 for ticker SMG.
# 2026-06-07 10:32:13,223, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2006
# 2026-06-07 10:32:13,239, 2113979629.py, 8, INFO, Processing year 2007 for ticker SMG.
# 2026-06-07 10:32:13,239, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2007
# 2026-06-07 10:32:13,271, 2113979629.py, 8, INFO, Processing year 2008 for ticker SMG.
# 2026-06-07 10:32:13,278, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2008
# 2026-06-07 10:32:13,287, 2113979629.py, 8, INFO, Processing year 2009 for ticker SMG.
# 2026-06-07 10:32:13,303, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2009
# 2026-06-07 10:32:13,319, 2113979629.py, 8, INFO, Processing year 2010 for ticker SMG.
# 2026-06-07 10:32:13,327, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2010
# 2026-06-07 10:32:13,341, 2113979629.py, 8, INFO, Processing year 2011 for ticker SMG.
# 2026-06-07 10:32:13,350, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2011
# 2026-06-07 10:32:13,365, 2113979629.py, 8, INFO, Processing year 2012 for ticker SMG.
# 2026-06-07 10:32:13,378, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2012
# 2026-06-07 10:32:13,399, 2113979629.py, 8, INFO, Processing year 2013 for ticker SMG.
# 2026-06-07 10:32:13,399, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2013
# 2026-06-07 10:32:13,412, 2113979629.py, 8, INFO, Processing year 2014 for ticker SMG.
# 2026-06-07 10:32:13,427, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2014
# 2026-06-07 10:32:13,447, 2113979629.py, 8, INFO, Processing year 2015 for ticker SMG.
# 2026-06-07 10:32:13,447, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2015
# 2026-06-07 10:32:13,474, 2113979629.py, 8, INFO, Processing year 2016 for ticker SMG.
# 2026-06-07 10:32:13,478, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2016
# 2026-06-07 10:32:13,494, 2113979629.py, 8, INFO, Processing year 2017 for ticker SMG.
# 2026-06-07 10:32:13,506, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2017
# 2026-06-07 10:32:13,526, 2113979629.py, 8, INFO, Processing year 2018 for ticker SMG.
# 2026-06-07 10:32:13,533, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2018
# 2026-06-07 10:32:13,555, 2113979629.py, 8, INFO, Processing year 2019 for ticker SMG.
# 2026-06-07 10:32:13,561, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2019
# 2026-06-07 10:32:13,575, 2113979629.py, 8, INFO, Processing year 2020 for ticker SMG.
# 2026-06-07 10:32:13,575, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SMG\SMG_2020
# 2026-06-07 10:32:13,605, 2113979629.py, 4, INFO, Processing ticker: MOH
# 2026-06-07 10:32:13,620, 2113979629.py, 8, INFO, Processing year 2003 for ticker MOH.
# 2026-06-07 10:32:13,629, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2003
# 2026-06-07 10:32:13,657, 2113979629.py, 8, INFO, Processing year 2004 for ticker MOH.
# 2026-06-07 10:32:13,665, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2004
# 2026-06-07 10:32:13,682, 2113979629.py, 8, INFO, Processing year 2005 for ticker MOH.
# 2026-06-07 10:32:13,689, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2005
# 2026-06-07 10:32:13,707, 2113979629.py, 8, INFO, Processing year 2006 for ticker MOH.
# 2026-06-07 10:32:13,713, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2006
# 2026-06-07 10:32:13,731, 2113979629.py, 8, INFO, Processing year 2007 for ticker MOH.
# 2026-06-07 10:32:13,731, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2007
# 2026-06-07 10:32:13,762, 2113979629.py, 8, INFO, Processing year 2008 for ticker MOH.
# 2026-06-07 10:32:13,769, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2008
# 2026-06-07 10:32:13,777, 2113979629.py, 8, INFO, Processing year 2009 for ticker MOH.
# 2026-06-07 10:32:13,793, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2009
# 2026-06-07 10:32:13,809, 2113979629.py, 8, INFO, Processing year 2010 for ticker MOH.
# 2026-06-07 10:32:13,818, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2010
# 2026-06-07 10:32:13,834, 2113979629.py, 8, INFO, Processing year 2011 for ticker MOH.
# 2026-06-07 10:32:13,841, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2011
# 2026-06-07 10:32:13,868, 2113979629.py, 8, INFO, Processing year 2012 for ticker MOH.
# 2026-06-07 10:32:13,874, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2012
# 2026-06-07 10:32:13,887, 2113979629.py, 8, INFO, Processing year 2013 for ticker MOH.
# 2026-06-07 10:32:13,887, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2013
# 2026-06-07 10:32:13,905, 2113979629.py, 8, INFO, Processing year 2014 for ticker MOH.
# 2026-06-07 10:32:13,919, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2014
# 2026-06-07 10:32:13,945, 2113979629.py, 8, INFO, Processing year 2015 for ticker MOH.
# 2026-06-07 10:32:13,950, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2015
# 2026-06-07 10:32:13,971, 2113979629.py, 8, INFO, Processing year 2016 for ticker MOH.
# 2026-06-07 10:32:13,976, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2016
# 2026-06-07 10:32:13,998, 2113979629.py, 8, INFO, Processing year 2017 for ticker MOH.
# 2026-06-07 10:32:14,005, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2017
# 2026-06-07 10:32:14,014, 2113979629.py, 8, INFO, Processing year 2018 for ticker MOH.
# 2026-06-07 10:32:14,030, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2018
# 2026-06-07 10:32:14,047, 2113979629.py, 8, INFO, Processing year 2019 for ticker MOH.
# 2026-06-07 10:32:14,055, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2019
# 2026-06-07 10:32:14,061, 2113979629.py, 8, INFO, Processing year 2020 for ticker MOH.
# 2026-06-07 10:32:14,077, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/MOH\MOH_2020
# 2026-06-07 10:32:14,094, 2113979629.py, 4, INFO, Processing ticker: AMH
# 2026-06-07 10:32:14,108, 2113979629.py, 8, INFO, Processing year 2013 for ticker AMH.
# 2026-06-07 10:32:14,124, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/AMH\AMH_
 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2018
# 2026-06-07 10:32:45,406, 2113979629.py, 8, INFO, Processing year 2019 for ticker TEF.
# 2026-06-07 10:32:45,420, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2019
# 2026-06-07 10:32:45,435, 2113979629.py, 8, INFO, Processing year 2020 for ticker TEF.
# 2026-06-07 10:32:45,458, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/TEF\TEF_2020
# 2026-06-07 10:32:45,487, 2113979629.py, 4, INFO, Processing ticker: SYNH
# 2026-06-07 10:32:45,502, 2113979629.py, 8, INFO, Processing year 2014 for ticker SYNH.
# 2026-06-07 10:32:45,507, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2014
# 2026-06-07 10:32:45,541, 2113979629.py, 8, INFO, Processing year 2015 for ticker SYNH.
# 2026-06-07 10:32:45,548, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2015
# 2026-06-07 10:32:45,574, 2113979629.py, 8, INFO, Processing year 2016 for ticker SYNH.
# 2026-06-07 10:32:45,576, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2016
# 2026-06-07 10:32:45,608, 2113979629.py, 8, INFO, Processing year 2017 for ticker SYNH.
# 2026-06-07 10:32:45,618, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2017
# 2026-06-07 10:32:45,644, 2113979629.py, 8, INFO, Processing year 2018 for ticker SYNH.
# 2026-06-07 10:32:45,651, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2018
# 2026-06-07 10:32:45,677, 2113979629.py, 8, INFO, Processing year 2019 for ticker SYNH.
# 2026-06-07 10:32:45,692, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2019
# 2026-06-07 10:32:45,717, 2113979629.py, 8, INFO, Processing year 2020 for ticker SYNH.
# 2026-06-07 10:32:45,724, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/SYNH\SYNH_2020
# 2026-06-07 10:32:45,758, 2113979629.py, 4, INFO, Processing ticker: KEY
# 2026-06-07 10:32:45,774, 2113979629.py, 8, INFO, Processing year 1987 for ticker KEY.
# 2026-06-07 10:32:45,786, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1987
# 2026-06-07 10:32:45,815, 2113979629.py, 8, INFO, Processing year 1988 for ticker KEY.
# 2026-06-07 10:32:45,823, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1988
# 2026-06-07 10:32:45,835, 2113979629.py, 8, INFO, Processing year 1989 for ticker KEY.
# 2026-06-07 10:32:45,857, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1989
# 2026-06-07 10:32:45,883, 2113979629.py, 8, INFO, Processing year 1990 for ticker KEY.
# 2026-06-07 10:32:45,892, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1990
# 2026-06-07 10:32:45,920, 2113979629.py, 8, INFO, Processing year 1991 for ticker KEY.
# 2026-06-07 10:32:45,928, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1991
# 2026-06-07 10:32:45,953, 2113979629.py, 8, INFO, Processing year 1992 for ticker KEY.
# 2026-06-07 10:32:45,961, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1992
# 2026-06-07 10:32:45,985, 2113979629.py, 8, INFO, Processing year 1993 for ticker KEY.
# 2026-06-07 10:32:45,996, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1993
# 2026-06-07 10:32:46,038, 2113979629.py, 8, INFO, Processing year 1994 for ticker KEY.
# 2026-06-07 10:32:46,043, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1994
# 2026-06-07 10:32:46,070, 2113979629.py, 8, INFO, Processing year 1995 for ticker KEY.
# 2026-06-07 10:32:46,074, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1995
# 2026-06-07 10:32:46,105, 2113979629.py, 8, INFO, Processing year 1996 for ticker KEY.
# 2026-06-07 10:32:46,112, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1996
# 2026-06-07 10:32:46,138, 2113979629.py, 8, INFO, Processing year 1997 for ticker KEY.
# 2026-06-07 10:32:46,144, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1997
# 2026-06-07 10:32:46,173, 2113979629.py, 8, INFO, Processing year 1998 for ticker KEY.
# 2026-06-07 10:32:46,180, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1998
# 2026-06-07 10:32:46,209, 2113979629.py, 8, INFO, Processing year 1999 for ticker KEY.
# 2026-06-07 10:32:46,209, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_1999
# 2026-06-07 10:32:46,244, 2113979629.py, 8, INFO, Processing year 2000 for ticker KEY.
# 2026-06-07 10:32:46,252, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2000
# 2026-06-07 10:32:46,269, 2113979629.py, 8, INFO, Processing year 2001 for ticker KEY.
# 2026-06-07 10:32:46,286, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2001
# 2026-06-07 10:32:46,309, 2113979629.py, 8, INFO, Processing year 2002 for ticker KEY.
# 2026-06-07 10:32:46,320, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2002
# 2026-06-07 10:32:46,339, 2113979629.py, 8, INFO, Processing year 2003 for ticker KEY.
# 2026-06-07 10:32:46,355, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2003
# 2026-06-07 10:32:46,374, 2113979629.py, 8, INFO, Processing year 2004 for ticker KEY.
# 2026-06-07 10:32:46,389, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2004
# 2026-06-07 10:32:46,410, 2113979629.py, 8, INFO, Processing year 2005 for ticker KEY.
# 2026-06-07 10:32:46,422, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2005
# 2026-06-07 10:32:46,446, 2113979629.py, 8, INFO, Processing year 2006 for ticker KEY.
# 2026-06-07 10:32:46,456, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2006
# 2026-06-07 10:32:46,474, 2113979629.py, 8, INFO, Processing year 2007 for ticker KEY.
# 2026-06-07 10:32:46,490, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2007
# 2026-06-07 10:32:46,514, 2113979629.py, 8, INFO, Processing year 2008 for ticker KEY.
# 2026-06-07 10:32:46,521, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2008
# 2026-06-07 10:32:46,541, 2113979629.py, 8, INFO, Processing year 2009 for ticker KEY.
# 2026-06-07 10:32:46,557, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2009
# 2026-06-07 10:32:46,582, 2113979629.py, 8, INFO, Processing year 2010 for ticker KEY.
# 2026-06-07 10:32:46,590, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2010
# 2026-06-07 10:32:46,609, 2113979629.py, 8, INFO, Processing year 2011 for ticker KEY.
# 2026-06-07 10:32:46,625, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2011
# 2026-06-07 10:32:46,651, 2113979629.py, 8, INFO, Processing year 2012 for ticker KEY.
# 2026-06-07 10:32:46,659, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2012
# 2026-06-07 10:32:46,707, 2113979629.py, 8, INFO, Processing year 2013 for ticker KEY.
# 2026-06-07 10:32:46,711, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2013
# 2026-06-07 10:32:46,741, 2113979629.py, 8, INFO, Processing year 2014 for ticker KEY.
# 2026-06-07 10:32:46,753, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2014
# 2026-06-07 10:32:46,769, 2113979629.py, 8, INFO, Processing year 2015 for ticker KEY.
# 2026-06-07 10:32:46,785, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2015
# 2026-06-07 10:32:46,814, 2113979629.py, 8, INFO, Processing year 2016 for ticker KEY.
# 2026-06-07 10:32:46,823, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2016
# 2026-06-07 10:32:46,857, 2113979629.py, 8, INFO, Processing year 2017 for ticker KEY.
# 2026-06-07 10:32:46,859, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2017
# 2026-06-07 10:32:46,894, 2113979629.py, 8, INFO, Processing year 2018 for ticker KEY.
# 2026-06-07 10:32:46,902, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2018
# 2026-06-07 10:32:46,924, 2113979629.py, 8, INFO, Processing year 2019 for ticker KEY.
# 2026-06-07 10:32:46,939, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2019
# 2026-06-07 10:32:46,956, 2113979629.py, 8, INFO, Processing year 2020 for ticker KEY.
# 2026-06-07 10:32:46,975, 2113979629.py, 15, INFO, Writing data to path: ../../05_src/data/prices/KEY\KEY_2020

# %% [markdown]
# Why would we want to store data this way?
#
# + Data files are easier to maintain. We do not update old data, only recent data or the most recent "delta".
# + Parquet files, as long as they maintain a consistent schema, can all be read jointly.

# %% [markdown]
# # Load, Transform, and Save
#
# In this section, we will load the Parquet files we generated, transform the data, and save the resulting dataset.

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to obtain the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
_logs.info(f'Found {len(parquet_files)} parquet files for reading back into Dask.')

dd_px = dd.read_parquet(parquet_files).set_index("ticker")
# Out:
# 2026-06-07 10:33:38,545, 174194153.py, 4, INFO, Found 2045 parquet files for reading back into Dask.

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work similarly to Pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.
#
# In the code below, the following operation occurs:
#
# + Start with a Dask dataframe, `dd_px`.
# + Group the rows of this dataframe by the variable `ticker`, i.e., each group will contain the observations that pertain only to one ticker at a time. The `group_key` parameter controls whether an index entry is added with the value of the grouping variable (`ticker` in this case); if we made `group_keys=True`, we would have a duplicate `ticker` column.
# + For each group defined by a `ticker`, `apply()` the following calculation:
#
#     - Sort the values by `Date` in ascending order.
#     - Assign a new variable called `Close_lag_1` by shifting the position of the closing price (`Close`) by one position.
#     - Define the schema of the resulting dataframe. If we omit this specification, we would get a warning; however, the simplicity of the calculation ensures that Dask can determine the resulting schema.

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                           Date     Open     High      Low    Close Adj Close   Volume  source   Year
# npartitions=60
# ACN             datetime64[ns]  float64  float64  float64  float64   float64  float64  string  int32
# ALDX                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ...                        ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# ZIXI                       ...      ...      ...      ...      ...       ...      ...     ...    ...
# Dask Name: setindex, 2 expressions
# Expr=SetIndex(frame=ReadParquetFSSpec(7633709), _other='ticker', options={})

# %%
dd_shift = (
    dd_px
        .groupby('ticker', group_keys=False)
        .apply(
            lambda x: x.sort_values('Date', ascending = True)
                       .assign(Close_lag_1 = x['Close'].shift(1)), 
            meta = pd.DataFrame(data ={'Date': 'datetime64[ns]',
                    'Open': 'f8',
                    'High': 'f8',
                    'Low': 'f8',
                    'Close': 'f8',
                    'Adj Close': 'f8',
                    'Volume': 'i8',
                    'source': 'object',
                    'Year': 'int32',
                    'Close_lag_1': 'f8'},
                    index = pd.Index([], dtype=pd.StringDtype(), name='ticker'))
    ))

# %% [markdown]
# Finally, using the dataframe that we created above, we can now `assign` the `Returns` variable to the entire dataset.

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %% [markdown]
# Question: How do we know that we are not (erroneously) combining the last price of a ticker with the first price of the next ticker?

# %% [markdown]
# ## Lazy Execution
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# ACN             object  object  object  object  object    object  object  object  object      object  object
# ALDX               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZIXI               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZIXI               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(7633709), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x000002C911B30720>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until the computation is required.
# + To trigger an execution in dask use `.compute()` or execute a command that requires the actual values (for example, write to Parquet or SQL).

# %%
dd_rets.compute()
# Out:
#              Date   Open   High    Low  Close  Adj Close      Volume  \
# ticker
# ACN    2001-07-19  15.10  15.29  15.00  15.17  11.404394  34994300.0
# ACN    2001-07-20  15.05  15.05  14.80  15.01  11.284108   9238500.0
# ACN    2001-07-23  15.00  15.01  14.55  15.00  11.276587   7501000.0
# ACN    2001-07-24  14.95  14.97  14.70  14.86  11.171341   3537300.0
# ACN    2001-07-25  14.70  14.95  14.65  14.95  11.238999   4208100.0
# ...           ...    ...    ...    ...    ...        ...         ...
# ZIXI   2020-03-26   4.06   4.53   3.88   4.51   4.510000   1668500.0
# ZIXI   2020-03-27   4.49   4.71   4.10   4.60   4.600000   1146800.0
# ZIXI   2020-03-30   4.83   4.87   4.44   4.64   4.640000   1212000.0
# ZIXI   2020-03-31   4.60   4.69   4.10   4.31   4.310000   1057200.0
# ZIXI   2020-04-01   4.11   4.16   3.80   3.82   3.820000    539500.0
#
#           source  Year  Close_lag_1   Returns
# ticker
# ACN      ACN.csv  2001          NaN       NaN
# ACN      ACN.csv  2001        15.17 -0.010547
# ACN      ACN.csv  2001        15.01 -0.000666
# ACN      ACN.csv  2001        15.00 -0.009333
# ACN      ACN.csv  2001        14.86  0.006057
# ...          ...   ...          ...       ...
# ZIXI    ZIXI.csv  2020         4.04  0.116337
# ZIXI    ZIXI.csv  2020         4.00  0.150000
# ZIXI    ZIXI.csv  2020         3.85  0.205195
# ZIXI    ZIXI.csv  2020         3.77  0.143236
# ZIXI    ZIXI.csv  2020         3.78  0.010582
#
# [239659 rows x 11 columns]

# %%
df = dd_rets.compute()
df.to_csv("test.csv")

# %%
df.head()
# Out:
#              Date   Open   High    Low  Close  Adj Close      Volume   source  \
# ticker
# ACN    2001-07-19  15.10  15.29  15.00  15.17  11.404394  34994300.0  ACN.csv
# ACN    2001-07-20  15.05  15.05  14.80  15.01  11.284108   9238500.0  ACN.csv
# ACN    2001-07-23  15.00  15.01  14.55  15.00  11.276587   7501000.0  ACN.csv
# ACN    2001-07-24  14.95  14.97  14.70  14.86  11.171341   3537300.0  ACN.csv
# ACN    2001-07-25  14.70  14.95  14.65  14.95  11.238999   4208100.0  ACN.csv
#
#         Year  Close_lag_1   Returns
# ticker
# ACN     2001          NaN       NaN
# ACN     2001   153.839996 -0.902431
# ACN     2001   154.550003 -0.902944
# ACN     2001   156.380005 -0.904975
# ACN     2001   157.669998 -0.905182

# %% [markdown]
# ## Save
#
# With our transformed data, we can now save the new feature to a Parquet file. We will need to answer the following questions depending on our context, setup, and available resources:
#
# + Should we keep the same namespace?
# + Should we save all columns?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                   Date    Open    High     Low   Close Adj Close  Volume  source    Year Close_lag_1 Returns
# npartitions=60
# ACN             object  object  object  object  object    object  object  object  object      object  object
# ALDX               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ...                ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZIXI               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# ZIXI               ...     ...     ...     ...     ...       ...     ...     ...     ...         ...     ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(7633709), _other='ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x000002C911B30720>, args=(), kwargs={})))

# %%
# Clean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, 
                   overwrite = True, 
                   schema={
                       'Date': 'timestamp[ns]',
                       'Open': 'float64',
                       'High': 'float64',
                       'Low': 'float64',
                       'Close': 'float64',
                       'Adj Close': 'float64',
                       'Volume': 'int64',
                       'source': 'string',
                       'Year': 'int32',
                       'Close_lag_1': 'float64',
                       'Returns': 'float64',
                       'ticker': 'large_string'
                   })

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `../../05_src/stock_prices/data_manager.py`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %%
from stock_prices.data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.process_sample_files()
# Out:
# 2026-06-07 10:35:22,647, data_manager.py, 110, INFO, Processing sample of tickers
# 2026-06-07 10:35:22,647, data_manager.py, 117, INFO, Getting file list from ../../05_src/data/prices_csv/
# 2026-06-07 10:35:22,683, data_manager.py, 119, INFO, Found 5884 files in ../../05_src/data/prices_csv/
# 2026-06-07 10:35:22,684, data_manager.py, 126, INFO, Selecting sample of files
# 2026-06-07 10:35:22,686, data_manager.py, 132, INFO, Selected 30 files
# 2026-06-07 10:35:22,688, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\ECT.csv
# 2026-06-07 10:35:22,690, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\ECT.csv
# 2026-06-07 10:35:22,746, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:22,753, data_manager.py, 157, INFO, Processing ticker: ECT
# 2026-06-07 10:35:22,755, data_manager.py, 161, INFO, Processing year 2010 for ticker ECT.
# 2026-06-07 10:35:22,774, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2010
# 2026-06-07 10:35:22,805, data_manager.py, 161, INFO, Processing year 2011 for ticker ECT.
# 2026-06-07 10:35:22,805, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2011
# 2026-06-07 10:35:22,843, data_manager.py, 161, INFO, Processing year 2012 for ticker ECT.
# 2026-06-07 10:35:22,849, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2012
# 2026-06-07 10:35:22,875, data_manager.py, 161, INFO, Processing year 2013 for ticker ECT.
# 2026-06-07 10:35:22,880, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2013
# 2026-06-07 10:35:22,903, data_manager.py, 161, INFO, Processing year 2014 for ticker ECT.
# 2026-06-07 10:35:22,910, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2014
# 2026-06-07 10:35:22,936, data_manager.py, 161, INFO, Processing year 2015 for ticker ECT.
# 2026-06-07 10:35:22,943, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2015
# 2026-06-07 10:35:22,961, data_manager.py, 161, INFO, Processing year 2016 for ticker ECT.
# 2026-06-07 10:35:22,975, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2016
# 2026-06-07 10:35:22,998, data_manager.py, 161, INFO, Processing year 2017 for ticker ECT.
# 2026-06-07 10:35:23,007, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2017
# 2026-06-07 10:35:23,028, data_manager.py, 161, INFO, Processing year 2018 for ticker ECT.
# 2026-06-07 10:35:23,041, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2018
# 2026-06-07 10:35:23,070, data_manager.py, 161, INFO, Processing year 2019 for ticker ECT.
# 2026-06-07 10:35:23,074, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2019
# 2026-06-07 10:35:23,100, data_manager.py, 161, INFO, Processing year 2020 for ticker ECT.
# 2026-06-07 10:35:23,111, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ECT\ECT_2020
# 2026-06-07 10:35:23,148, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\MNPR.csv
# 2026-06-07 10:35:23,148, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\MNPR.csv
# 2026-06-07 10:35:23,177, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:23,178, data_manager.py, 157, INFO, Processing ticker: MNPR
# 2026-06-07 10:35:23,180, data_manager.py, 161, INFO, Processing year 2019 for ticker MNPR.
# 2026-06-07 10:35:23,188, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MNPR\MNPR_2019
# 2026-06-07 10:35:23,224, data_manager.py, 161, INFO, Processing year 2020 for ticker MNPR.
# 2026-06-07 10:35:23,225, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MNPR\MNPR_2020
# 2026-06-07 10:35:23,257, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\SNDX.csv
# 2026-06-07 10:35:23,259, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\SNDX.csv
# 2026-06-07 10:35:23,279, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:23,281, data_manager.py, 157, INFO, Processing ticker: SNDX
# 2026-06-07 10:35:23,283, data_manager.py, 161, INFO, Processing year 2016 for ticker SNDX.
# 2026-06-07 10:35:23,290, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SNDX\SNDX_2016
# 2026-06-07 10:35:23,320, data_manager.py, 161, INFO, Processing year 2017 for ticker SNDX.
# 2026-06-07 10:35:23,338, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SNDX\SNDX_2017
# 2026-06-07 10:35:23,383, data_manager.py, 161, INFO, Processing year 2018 for ticker SNDX.
# 2026-06-07 10:35:23,392, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SNDX\SNDX_2018
# 2026-06-07 10:35:23,406, data_manager.py, 161, INFO, Processing year 2019 for ticker SNDX.
# 2026-06-07 10:35:23,425, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SNDX\SNDX_2019
# 2026-06-07 10:35:23,445, data_manager.py, 161, INFO, Processing year 2020 for ticker SNDX.
# 2026-06-07 10:35:23,458, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SNDX\SNDX_2020
# 2026-06-07 10:35:23,483, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\MBUU.csv
# 2026-06-07 10:35:23,484, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\MBUU.csv
# 2026-06-07 10:35:23,507, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:23,508, data_manager.py, 157, INFO, Processing ticker: MBUU
# 2026-06-07 10:35:23,513, data_manager.py, 161, INFO, Processing year 2014 for ticker MBUU.
# 2026-06-07 10:35:23,524, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MBUU\MBUU_2014
# 2026-06-07 10:35:23,554, data_manager.py, 161, INFO, Processing year 2015 for ticker MBUU.
# 2026-06-07 10:35:23,557, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MBUU\MBUU_2015
# 2026-06-07 10:35:23,577, data_manager.py, 161, INFO, Processing year 2016 for ticker MBUU.
# 2026-06-07 10:35:23,592, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MBUU\MBUU_2016
# 2026-06-07 10:35:23,616, data_manager.py, 161, INFO, Processing year 2017 for ticker MBUU.
# 2026-06-07 10:35:23,625, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MBUU\MBUU_2017
# 2026-06-07 10:35:23,649, data_manager.py, 161, INFO, Processing year 2018 for ticker MBUU.
# 2026-06-07 10:35:23,657, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MBUU\MBUU_2018
# 2026-06-07 10:35:23,688, data_manager.py, 161, INFO, Processing year 2019 for ticker MBUU.
# 2026-06-07 10:35:23,690, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MBUU\MBUU_2019
# 2026-06-07 10:35:23,726, data_manager.py, 161, INFO, Processing year 2020 for ticker MBUU.
# 2026-06-07 10:35:23,738, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MBUU\MBUU_2020
# 2026-06-07 10:35:23,761, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\KGC.csv
# 2026-06-07 10:35:23,762, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\KGC.csv
# 2026-06-07 10:35:23,795, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:23,797, data_manager.py, 157, INFO, Processing ticker: KGC
# 2026-06-07 10:35:23,800, data_manager.py, 161, INFO, Processing year 1981 for ticker KGC.
# 2026-06-07 10:35:23,802, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1981
# 2026-06-07 10:35:23,825, data_manager.py, 161, INFO, Processing year 1982 for ticker KGC.
# 2026-06-07 10:35:23,825, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1982
# 2026-06-07 10:35:23,852, data_manager.py, 161, INFO, Processing year 1983 for ticker KGC.
# 2026-06-07 10:35:23,859, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1983
# 2026-06-07 10:35:23,872, data_manager.py, 161, INFO, Processing year 1984 for ticker KGC.
# 2026-06-07 10:35:23,872, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1984
# 2026-06-07 10:35:23,905, data_manager.py, 161, INFO, Processing year 1985 for ticker KGC.
# 2026-06-07 10:35:23,917, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1985
# 2026-06-07 10:35:23,935, data_manager.py, 161, INFO, Processing year 1986 for ticker KGC.
# 2026-06-07 10:35:23,935, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1986
# 2026-06-07 10:35:23,958, data_manager.py, 161, INFO, Processing year 1987 for ticker KGC.
# 2026-06-07 10:35:23,972, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1987
# 2026-06-07 10:35:23,998, data_manager.py, 161, INFO, Processing year 1988 for ticker KGC.
# 2026-06-07 10:35:24,004, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1988
# 2026-06-07 10:35:24,032, data_manager.py, 161, INFO, Processing year 1989 for ticker KGC.
# 2026-06-07 10:35:24,042, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1989
# 2026-06-07 10:35:24,073, data_manager.py, 161, INFO, Processing year 1990 for ticker KGC.
# 2026-06-07 10:35:24,073, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1990
# 2026-06-07 10:35:24,107, data_manager.py, 161, INFO, Processing year 1991 for ticker KGC.
# 2026-06-07 10:35:24,122, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1991
# 2026-06-07 10:35:24,147, data_manager.py, 161, INFO, Processing year 1992 for ticker KGC.
# 2026-06-07 10:35:24,156, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1992
# 2026-06-07 10:35:24,189, data_manager.py, 161, INFO, Processing year 1993 for ticker KGC.
# 2026-06-07 10:35:24,203, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1993
# 2026-06-07 10:35:24,255, data_manager.py, 161, INFO, Processing year 1994 for ticker KGC.
# 2026-06-07 10:35:24,259, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1994
# 2026-06-07 10:35:24,298, data_manager.py, 161, INFO, Processing year 1995 for ticker KGC.
# 2026-06-07 10:35:24,306, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1995
# 2026-06-07 10:35:24,324, data_manager.py, 161, INFO, Processing year 1996 for ticker KGC.
# 2026-06-07 10:35:24,335, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1996
# 2026-06-07 10:35:24,361, data_manager.py, 161, INFO, Processing year 1997 for ticker KGC.
# 2026-06-07 10:35:24,362, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1997
# 2026-06-07 10:35:24,391, data_manager.py, 161, INFO, Processing year 1998 for ticker KGC.
# 2026-06-07 10:35:24,398, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1998
# 2026-06-07 10:35:24,426, data_manager.py, 161, INFO, Processing year 1999 for ticker KGC.
# 2026-06-07 10:35:24,428, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_1999
# 2026-06-07 10:35:24,459, data_manager.py, 161, INFO, Processing year 2000 for ticker KGC.
# 2026-06-07 10:35:24,466, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2000
# 2026-06-07 10:35:24,490, data_manager.py, 161, INFO, Processing year 2001 for ticker KGC.
# 2026-06-07 10:35:24,491, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2001
# 2026-06-07 10:35:24,508, data_manager.py, 161, INFO, Processing year 2002 for ticker KGC.
# 2026-06-07 10:35:24,525, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2002
# 2026-06-07 10:35:24,542, data_manager.py, 161, INFO, Processing year 2003 for ticker KGC.
# 2026-06-07 10:35:24,559, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2003
# 2026-06-07 10:35:24,577, data_manager.py, 161, INFO, Processing year 2004 for ticker KGC.
# 2026-06-07 10:35:24,591, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2004
# 2026-06-07 10:35:24,608, data_manager.py, 161, INFO, Processing year 2005 for ticker KGC.
# 2026-06-07 10:35:24,623, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2005
# 2026-06-07 10:35:24,641, data_manager.py, 161, INFO, Processing year 2006 for ticker KGC.
# 2026-06-07 10:35:24,658, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2006
# 2026-06-07 10:35:24,689, data_manager.py, 161, INFO, Processing year 2007 for ticker KGC.
# 2026-06-07 10:35:24,696, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2007
# 2026-06-07 10:35:24,726, data_manager.py, 161, INFO, Processing year 2008 for ticker KGC.
# 2026-06-07 10:35:24,731, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2008
# 2026-06-07 10:35:24,757, data_manager.py, 161, INFO, Processing year 2009 for ticker KGC.
# 2026-06-07 10:35:24,763, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2009
# 2026-06-07 10:35:24,783, data_manager.py, 161, INFO, Processing year 2010 for ticker KGC.
# 2026-06-07 10:35:24,791, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2010
# 2026-06-07 10:35:24,811, data_manager.py, 161, INFO, Processing year 2011 for ticker KGC.
# 2026-06-07 10:35:24,820, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2011
# 2026-06-07 10:35:24,847, data_manager.py, 161, INFO, Processing year 2012 for ticker KGC.
# 2026-06-07 10:35:24,852, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2012
# 2026-06-07 10:35:24,869, data_manager.py, 161, INFO, Processing year 2013 for ticker KGC.
# 2026-06-07 10:35:24,869, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2013
# 2026-06-07 10:35:24,905, data_manager.py, 161, INFO, Processing year 2014 for ticker KGC.
# 2026-06-07 10:35:24,907, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2014
# 2026-06-07 10:35:24,941, data_manager.py, 161, INFO, Processing year 2015 for ticker KGC.
# 2026-06-07 10:35:24,948, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2015
# 2026-06-07 10:35:24,974, data_manager.py, 161, INFO, Processing year 2016 for ticker KGC.
# 2026-06-07 10:35:24,974, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2016
# 2026-06-07 10:35:25,008, data_manager.py, 161, INFO, Processing year 2017 for ticker KGC.
# 2026-06-07 10:35:25,023, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2017
# 2026-06-07 10:35:25,043, data_manager.py, 161, INFO, Processing year 2018 for ticker KGC.
# 2026-06-07 10:35:25,055, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2018
# 2026-06-07 10:35:25,074, data_manager.py, 161, INFO, Processing year 2019 for ticker KGC.
# 2026-06-07 10:35:25,074, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2019
# 2026-06-07 10:35:25,103, data_manager.py, 161, INFO, Processing year 2020 for ticker KGC.
# 2026-06-07 10:35:25,109, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/KGC\KGC_2020
# 2026-06-07 10:35:25,130, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\ICCH.csv
# 2026-06-07 10:35:25,130, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\ICCH.csv
# 2026-06-07 10:35:25,149, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:25,149, data_manager.py, 157, INFO, Processing ticker: ICCH
# 2026-06-07 10:35:25,154, data_manager.py, 161, INFO, Processing year 2017 for ticker ICCH.
# 2026-06-07 10:35:25,159, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ICCH\ICCH_2017
# 2026-06-07 10:35:25,174, data_manager.py, 161, INFO, Processing year 2018 for ticker ICCH.
# 2026-06-07 10:35:25,190, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ICCH\ICCH_2018
# 2026-06-07 10:35:25,218, data_manager.py, 161, INFO, Processing year 2019 for ticker ICCH.
# 2026-06-07 10:35:25,224, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ICCH\ICCH_2019
# 2026-06-07 10:35:25,341, data_manager.py, 161, INFO, Processing year 2020 for ticker ICCH.
# 2026-06-07 10:35:25,341, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ICCH\ICCH_2020
# 2026-06-07 10:35:25,386, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\BRY.csv
# 2026-06-07 10:35:25,387, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\BRY.csv
# 2026-06-07 10:35:25,427, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:25,429, data_manager.py, 157, INFO, Processing ticker: BRY
# 2026-06-07 10:35:25,434, data_manager.py, 161, INFO, Processing year 1987 for ticker BRY.
# 2026-06-07 10:35:25,442, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1987
# 2026-06-07 10:35:25,467, data_manager.py, 161, INFO, Processing year 1988 for ticker BRY.
# 2026-06-07 10:35:25,475, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1988
# 2026-06-07 10:35:25,486, data_manager.py, 161, INFO, Processing year 1989 for ticker BRY.
# 2026-06-07 10:35:25,504, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1989
# 2026-06-07 10:35:25,534, data_manager.py, 161, INFO, Processing year 1990 for ticker BRY.
# 2026-06-07 10:35:25,543, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1990
# 2026-06-07 10:35:25,576, data_manager.py, 161, INFO, Processing year 1991 for ticker BRY.
# 2026-06-07 10:35:25,576, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1991
# 2026-06-07 10:35:25,619, data_manager.py, 161, INFO, Processing year 1992 for ticker BRY.
# 2026-06-07 10:35:25,633, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1992
# 2026-06-07 10:35:25,675, data_manager.py, 161, INFO, Processing year 1993 for ticker BRY.
# 2026-06-07 10:35:25,683, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1993
# 2026-06-07 10:35:25,719, data_manager.py, 161, INFO, Processing year 1994 for ticker BRY.
# 2026-06-07 10:35:25,727, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1994
# 2026-06-07 10:35:25,754, data_manager.py, 161, INFO, Processing year 1995 for ticker BRY.
# 2026-06-07 10:35:25,762, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1995
# 2026-06-07 10:35:25,790, data_manager.py, 161, INFO, Processing year 1996 for ticker BRY.
# 2026-06-07 10:35:25,797, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1996
# 2026-06-07 10:35:25,825, data_manager.py, 161, INFO, Processing year 1997 for ticker BRY.
# 2026-06-07 10:35:25,825, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1997
# 2026-06-07 10:35:25,868, data_manager.py, 161, INFO, Processing year 1998 for ticker BRY.
# 2026-06-07 10:35:25,876, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1998
# 2026-06-07 10:35:25,903, data_manager.py, 161, INFO, Processing year 1999 for ticker BRY.
# 2026-06-07 10:35:25,909, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_1999
# 2026-06-07 10:35:25,935, data_manager.py, 161, INFO, Processing year 2000 for ticker BRY.
# 2026-06-07 10:35:25,943, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2000
# 2026-06-07 10:35:25,967, data_manager.py, 161, INFO, Processing year 2001 for ticker BRY.
# 2026-06-07 10:35:25,974, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2001
# 2026-06-07 10:35:25,986, data_manager.py, 161, INFO, Processing year 2002 for ticker BRY.
# 2026-06-07 10:35:25,986, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2002
# 2026-06-07 10:35:26,024, data_manager.py, 161, INFO, Processing year 2003 for ticker BRY.
# 2026-06-07 10:35:26,026, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2003
# 2026-06-07 10:35:26,064, data_manager.py, 161, INFO, Processing year 2004 for ticker BRY.
# 2026-06-07 10:35:26,074, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2004
# 2026-06-07 10:35:26,105, data_manager.py, 161, INFO, Processing year 2005 for ticker BRY.
# 2026-06-07 10:35:26,111, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2005
# 2026-06-07 10:35:26,137, data_manager.py, 161, INFO, Processing year 2006 for ticker BRY.
# 2026-06-07 10:35:26,144, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2006
# 2026-06-07 10:35:26,172, data_manager.py, 161, INFO, Processing year 2007 for ticker BRY.
# 2026-06-07 10:35:26,179, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2007
# 2026-06-07 10:35:26,209, data_manager.py, 161, INFO, Processing year 2008 for ticker BRY.
# 2026-06-07 10:35:26,209, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2008
# 2026-06-07 10:35:26,241, data_manager.py, 161, INFO, Processing year 2009 for ticker BRY.
# 2026-06-07 10:35:26,247, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2009
# 2026-06-07 10:35:26,274, data_manager.py, 161, INFO, Processing year 2010 for ticker BRY.
# 2026-06-07 10:35:26,275, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2010
# 2026-06-07 10:35:26,313, data_manager.py, 161, INFO, Processing year 2011 for ticker BRY.
# 2026-06-07 10:35:26,321, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2011
# 2026-06-07 10:35:26,366, data_manager.py, 161, INFO, Processing year 2012 for ticker BRY.
# 2026-06-07 10:35:26,383, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2012
# 2026-06-07 10:35:26,443, data_manager.py, 161, INFO, Processing year 2013 for ticker BRY.
# 2026-06-07 10:35:26,456, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2013
# 2026-06-07 10:35:26,493, data_manager.py, 161, INFO, Processing year 2014 for ticker BRY.
# 2026-06-07 10:35:26,500, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2014
# 2026-06-07 10:35:26,523, data_manager.py, 161, INFO, Processing year 2015 for ticker BRY.
# 2026-06-07 10:35:26,523, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2015
# 2026-06-07 10:35:26,553, data_manager.py, 161, INFO, Processing year 2016 for ticker BRY.
# 2026-06-07 10:35:26,558, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2016
# 2026-06-07 10:35:26,573, data_manager.py, 161, INFO, Processing year 2017 for ticker BRY.
# 2026-06-07 10:35:26,585, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2017
# 2026-06-07 10:35:26,608, data_manager.py, 161, INFO, Processing year 2018 for ticker BRY.
# 2026-06-07 10:35:26,615, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2018
# 2026-06-07 10:35:26,637, data_manager.py, 161, INFO, Processing year 2019 for ticker BRY.
# 2026-06-07 10:35:26,643, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2019
# 2026-06-07 10:35:26,658, data_manager.py, 161, INFO, Processing year 2020 for ticker BRY.
# 2026-06-07 10:35:26,670, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/BRY\BRY_2020
# 2026-06-07 10:35:26,691, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\MINDP.csv
# 2026-06-07 10:35:26,693, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\MINDP.csv
# 2026-06-07 10:35:26,720, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:26,721, data_manager.py, 157, INFO, Processing ticker: MINDP
# 2026-06-07 10:35:26,724, data_manager.py, 161, INFO, Processing year 2016 for ticker MINDP.
# 2026-06-07 10:35:26,729, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MINDP\MINDP_2016
# 2026-06-07 10:35:26,737, data_manager.py, 161, INFO, Processing year 2017 for ticker MINDP.
# 2026-06-07 10:35:26,753, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MINDP\MINDP_2017
# 2026-06-07 10:35:26,774, data_manager.py, 161, INFO, Processing year 2018 for ticker MINDP.
# 2026-06-07 10:35:26,776, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MINDP\MINDP_2018
# 2026-06-07 10:35:26,803, data_manager.py, 161, INFO, Processing year 2019 for ticker MINDP.
# 2026-06-07 10:35:26,808, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MINDP\MINDP_2019
# 2026-06-07 10:35:26,839, data_manager.py, 161, INFO, Processing year 2020 for ticker MINDP.
# 2026-06-07 10:35:26,845, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MINDP\MINDP_2020
# 2026-06-07 10:35:26,871, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\HAL.csv
# 2026-06-07 10:35:26,872, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\HAL.csv
# 2026-06-07 10:35:26,911, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:26,913, data_manager.py, 157, INFO, Processing ticker: HAL
# 2026-06-07 10:35:26,916, data_manager.py, 161, INFO, Processing year 1972 for ticker HAL.
# 2026-06-07 10:35:26,919, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1972
# 2026-06-07 10:35:26,942, data_manager.py, 161, INFO, Processing year 1973 for ticker HAL.
# 2026-06-07 10:35:26,947, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1973
# 2026-06-07 10:35:26,965, data_manager.py, 161, INFO, Processing year 1974 for ticker HAL.
# 2026-06-07 10:35:26,972, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1974
# 2026-06-07 10:35:26,991, data_manager.py, 161, INFO, Processing year 1975 for ticker HAL.
# 2026-06-07 10:35:26,991, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1975
# 2026-06-07 10:35:27,019, data_manager.py, 161, INFO, Processing year 1976 for ticker HAL.
# 2026-06-07 10:35:27,025, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1976
# 2026-06-07 10:35:27,058, data_manager.py, 161, INFO, Processing year 1977 for ticker HAL.
# 2026-06-07 10:35:27,060, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1977
# 2026-06-07 10:35:27,094, data_manager.py, 161, INFO, Processing year 1978 for ticker HAL.
# 2026-06-07 10:35:27,100, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1978
# 2026-06-07 10:35:27,121, data_manager.py, 161, INFO, Processing year 1979 for ticker HAL.
# 2026-06-07 10:35:27,124, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1979
# 2026-06-07 10:35:27,145, data_manager.py, 161, INFO, Processing year 1980 for ticker HAL.
# 2026-06-07 10:35:27,152, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1980
# 2026-06-07 10:35:27,175, data_manager.py, 161, INFO, Processing year 1981 for ticker HAL.
# 2026-06-07 10:35:27,175, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1981
# 2026-06-07 10:35:27,205, data_manager.py, 161, INFO, Processing year 1982 for ticker HAL.
# 2026-06-07 10:35:27,211, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1982
# 2026-06-07 10:35:27,225, data_manager.py, 161, INFO, Processing year 1983 for ticker HAL.
# 2026-06-07 10:35:27,239, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1983
# 2026-06-07 10:35:27,273, data_manager.py, 161, INFO, Processing year 1984 for ticker HAL.
# 2026-06-07 10:35:27,280, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1984
# 2026-06-07 10:35:27,305, data_manager.py, 161, INFO, Processing year 1985 for ticker HAL.
# 2026-06-07 10:35:27,309, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1985
# 2026-06-07 10:35:27,336, data_manager.py, 161, INFO, Processing year 1986 for ticker HAL.
# 2026-06-07 10:35:27,342, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1986
# 2026-06-07 10:35:27,365, data_manager.py, 161, INFO, Processing year 1987 for ticker HAL.
# 2026-06-07 10:35:27,371, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1987
# 2026-06-07 10:35:27,389, data_manager.py, 161, INFO, Processing year 1988 for ticker HAL.
# 2026-06-07 10:35:27,392, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1988
# 2026-06-07 10:35:27,408, data_manager.py, 161, INFO, Processing year 1989 for ticker HAL.
# 2026-06-07 10:35:27,421, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1989
# 2026-06-07 10:35:27,439, data_manager.py, 161, INFO, Processing year 1990 for ticker HAL.
# 2026-06-07 10:35:27,444, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1990
# 2026-06-07 10:35:27,464, data_manager.py, 161, INFO, Processing year 1991 for ticker HAL.
# 2026-06-07 10:35:27,470, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1991
# 2026-06-07 10:35:27,491, data_manager.py, 161, INFO, Processing year 1992 for ticker HAL.
# 2026-06-07 10:35:27,505, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1992
# 2026-06-07 10:35:27,526, data_manager.py, 161, INFO, Processing year 1993 for ticker HAL.
# 2026-06-07 10:35:27,541, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1993
# 2026-06-07 10:35:27,558, data_manager.py, 161, INFO, Processing year 1994 for ticker HAL.
# 2026-06-07 10:35:27,573, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1994
# 2026-06-07 10:35:27,592, data_manager.py, 161, INFO, Processing year 1995 for ticker HAL.
# 2026-06-07 10:35:27,596, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1995
# 2026-06-07 10:35:27,609, data_manager.py, 161, INFO, Processing year 1996 for ticker HAL.
# 2026-06-07 10:35:27,621, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1996
# 2026-06-07 10:35:27,642, data_manager.py, 161, INFO, Processing year 1997 for ticker HAL.
# 2026-06-07 10:35:27,647, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1997
# 2026-06-07 10:35:27,659, data_manager.py, 161, INFO, Processing year 1998 for ticker HAL.
# 2026-06-07 10:35:27,676, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1998
# 2026-06-07 10:35:27,701, data_manager.py, 161, INFO, Processing year 1999 for ticker HAL.
# 2026-06-07 10:35:27,708, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_1999
# 2026-06-07 10:35:27,725, data_manager.py, 161, INFO, Processing year 2000 for ticker HAL.
# 2026-06-07 10:35:27,740, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2000
# 2026-06-07 10:35:27,767, data_manager.py, 161, INFO, Processing year 2001 for ticker HAL.
# 2026-06-07 10:35:27,777, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2001
# 2026-06-07 10:35:27,823, data_manager.py, 161, INFO, Processing year 2002 for ticker HAL.
# 2026-06-07 10:35:27,832, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2002
# 2026-06-07 10:35:27,869, data_manager.py, 161, INFO, Processing year 2003 for ticker HAL.
# 2026-06-07 10:35:27,877, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2003
# 2026-06-07 10:35:27,915, data_manager.py, 161, INFO, Processing year 2004 for ticker HAL.
# 2026-06-07 10:35:27,924, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2004
# 2026-06-07 10:35:27,954, data_manager.py, 161, INFO, Processing year 2005 for ticker HAL.
# 2026-06-07 10:35:27,959, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2005
# 2026-06-07 10:35:27,976, data_manager.py, 161, INFO, Processing year 2006 for ticker HAL.
# 2026-06-07 10:35:27,989, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2006
# 2026-06-07 10:35:28,012, data_manager.py, 161, INFO, Processing year 2007 for ticker HAL.
# 2026-06-07 10:35:28,019, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2007
# 2026-06-07 10:35:28,041, data_manager.py, 161, INFO, Processing year 2008 for ticker HAL.
# 2026-06-07 10:35:28,041, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2008
# 2026-06-07 10:35:28,074, data_manager.py, 161, INFO, Processing year 2009 for ticker HAL.
# 2026-06-07 10:35:28,075, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2009
# 2026-06-07 10:35:28,103, data_manager.py, 161, INFO, Processing year 2010 for ticker HAL.
# 2026-06-07 10:35:28,109, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2010
# 2026-06-07 10:35:28,127, data_manager.py, 161, INFO, Processing year 2011 for ticker HAL.
# 2026-06-07 10:35:28,132, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2011
# 2026-06-07 10:35:28,142, data_manager.py, 161, INFO, Processing year 2012 for ticker HAL.
# 2026-06-07 10:35:28,156, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2012
# 2026-06-07 10:35:28,174, data_manager.py, 161, INFO, Processing year 2013 for ticker HAL.
# 2026-06-07 10:35:28,178, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2013
# 2026-06-07 10:35:28,192, data_manager.py, 161, INFO, Processing year 2014 for ticker HAL.
# 2026-06-07 10:35:28,205, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2014
# 2026-06-07 10:35:28,227, data_manager.py, 161, INFO, Processing year 2015 for ticker HAL.
# 2026-06-07 10:35:28,232, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2015
# 2026-06-07 10:35:28,257, data_manager.py, 161, INFO, Processing year 2016 for ticker HAL.
# 2026-06-07 10:35:28,264, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2016
# 2026-06-07 10:35:28,288, data_manager.py, 161, INFO, Processing year 2017 for ticker HAL.
# 2026-06-07 10:35:28,308, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2017
# 2026-06-07 10:35:28,387, data_manager.py, 161, INFO, Processing year 2018 for ticker HAL.
# 2026-06-07 10:35:28,400, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2018
# 2026-06-07 10:35:28,463, data_manager.py, 161, INFO, Processing year 2019 for ticker HAL.
# 2026-06-07 10:35:28,474, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2019
# 2026-06-07 10:35:28,505, data_manager.py, 161, INFO, Processing year 2020 for ticker HAL.
# 2026-06-07 10:35:28,512, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/HAL\HAL_2020
# 2026-06-07 10:35:28,557, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\ACA.csv
# 2026-06-07 10:35:28,559, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\ACA.csv
# 2026-06-07 10:35:28,600, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:28,600, data_manager.py, 157, INFO, Processing ticker: ACA
# 2026-06-07 10:35:28,607, data_manager.py, 161, INFO, Processing year 2018 for ticker ACA.
# 2026-06-07 10:35:28,615, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ACA\ACA_2018
# 2026-06-07 10:35:28,650, data_manager.py, 161, INFO, Processing year 2019 for ticker ACA.
# 2026-06-07 10:35:28,659, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ACA\ACA_2019
# 2026-06-07 10:35:28,675, data_manager.py, 161, INFO, Processing year 2020 for ticker ACA.
# 2026-06-07 10:35:28,691, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/ACA\ACA_2020
# 2026-06-07 10:35:28,710, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\GNCA.csv
# 2026-06-07 10:35:28,710, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\GNCA.csv
# 2026-06-07 10:35:28,738, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:28,739, data_manager.py, 157, INFO, Processing ticker: GNCA
# 2026-06-07 10:35:28,742, data_manager.py, 161, INFO, Processing year 2014 for ticker GNCA.
# 2026-06-07 10:35:28,742, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/GNCA\GNCA_2014
# 2026-06-07 10:35:28,776, data_manager.py, 161, INFO, Processing year 2015 for ticker GNCA.
# 2026-06-07 10:35:28,787, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/GNCA\GNCA_2015
# 2026-06-07 10:35:28,819, data_manager.py, 161, INFO, Processing year 2016 for ticker GNCA.
# 2026-06-07 10:35:28,829, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/GNCA\GNCA_2016
# 2026-06-07 10:35:28,854, data_manager.py, 161, INFO, Processing year 2017 for ticker GNCA.
# 2026-06-07 10:35:28,864, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/GNCA\GNCA_2017
# 2026-06-07 10:35:28,895, data_manager.py, 161, INFO, Processing year 2018 for ticker GNCA.
# 2026-06-07 10:35:28,901, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/GNCA\GNCA_2018
# 2026-06-07 10:35:28,922, data_manager.py, 161, INFO, Processing year 2019 for ticker GNCA.
# 2026-06-07 10:35:28,922, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/GNCA\GNCA_2019
# 2026-06-07 10:35:28,959, data_manager.py, 161, INFO, Processing year 2020 for ticker GNCA.
# 2026-06-07 10:35:28,969, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/GNCA\GNCA_2020
# 2026-06-07 10:35:28,997, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\PLBC.csv
# 2026-06-07 10:35:28,998, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\PLBC.csv
# 2026-06-07 10:35:29,028, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:29,028, data_manager.py, 157, INFO, Processing ticker: PLBC
# 2026-06-07 10:35:29,028, data_manager.py, 161, INFO, Processing year 2002 for ticker PLBC.
# 2026-06-07 10:35:29,042, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2002
# 2026-06-07 10:35:29,071, data_manager.py, 161, INFO, Processing year 2003 for ticker PLBC.
# 2026-06-07 10:35:29,079, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2003
# 2026-06-07 10:35:29,107, data_manager.py, 161, INFO, Processing year 2004 for ticker PLBC.
# 2026-06-07 10:35:29,113, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2004
# 2026-06-07 10:35:29,136, data_manager.py, 161, INFO, Processing year 2005 for ticker PLBC.
# 2026-06-07 10:35:29,141, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2005
# 2026-06-07 10:35:29,162, data_manager.py, 161, INFO, Processing year 2006 for ticker PLBC.
# 2026-06-07 10:35:29,172, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2006
# 2026-06-07 10:35:29,189, data_manager.py, 161, INFO, Processing year 2007 for ticker PLBC.
# 2026-06-07 10:35:29,194, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2007
# 2026-06-07 10:35:29,209, data_manager.py, 161, INFO, Processing year 2008 for ticker PLBC.
# 2026-06-07 10:35:29,221, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2008
# 2026-06-07 10:35:29,242, data_manager.py, 161, INFO, Processing year 2009 for ticker PLBC.
# 2026-06-07 10:35:29,242, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2009
# 2026-06-07 10:35:29,270, data_manager.py, 161, INFO, Processing year 2010 for ticker PLBC.
# 2026-06-07 10:35:29,281, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2010
# 2026-06-07 10:35:29,304, data_manager.py, 161, INFO, Processing year 2011 for ticker PLBC.
# 2026-06-07 10:35:29,310, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2011
# 2026-06-07 10:35:29,333, data_manager.py, 161, INFO, Processing year 2012 for ticker PLBC.
# 2026-06-07 10:35:29,340, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2012
# 2026-06-07 10:35:29,353, data_manager.py, 161, INFO, Processing year 2013 for ticker PLBC.
# 2026-06-07 10:35:29,376, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2013
# 2026-06-07 10:35:29,407, data_manager.py, 161, INFO, Processing year 2014 for ticker PLBC.
# 2026-06-07 10:35:29,414, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2014
# 2026-06-07 10:35:29,437, data_manager.py, 161, INFO, Processing year 2015 for ticker PLBC.
# 2026-06-07 10:35:29,442, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2015
# 2026-06-07 10:35:29,461, data_manager.py, 161, INFO, Processing year 2016 for ticker PLBC.
# 2026-06-07 10:35:29,473, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2016
# 2026-06-07 10:35:29,493, data_manager.py, 161, INFO, Processing year 2017 for ticker PLBC.
# 2026-06-07 10:35:29,493, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2017
# 2026-06-07 10:35:29,525, data_manager.py, 161, INFO, Processing year 2018 for ticker PLBC.
# 2026-06-07 10:35:29,525, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2018
# 2026-06-07 10:35:29,557, data_manager.py, 161, INFO, Processing year 2019 for ticker PLBC.
# 2026-06-07 10:35:29,562, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2019
# 2026-06-07 10:35:29,589, data_manager.py, 161, INFO, Processing year 2020 for ticker PLBC.
# 2026-06-07 10:35:29,594, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PLBC\PLBC_2020
# 2026-06-07 10:35:29,616, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\PFMT.csv
# 2026-06-07 10:35:29,617, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\PFMT.csv
# 2026-06-07 10:35:29,647, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:29,649, data_manager.py, 157, INFO, Processing ticker: PFMT
# 2026-06-07 10:35:29,662, data_manager.py, 161, INFO, Processing year 2012 for ticker PFMT.
# 2026-06-07 10:35:29,674, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PFMT\PFMT_2012
# 2026-06-07 10:35:29,709, data_manager.py, 161, INFO, Processing year 2013 for ticker PFMT.
# 2026-06-07 10:35:29,710, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PFMT\PFMT_2013
# 2026-06-07 10:35:29,741, data_manager.py, 161, INFO, Processing year 2014 for ticker PFMT.
# 2026-06-07 10:35:29,747, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PFMT\PFMT_2014
# 2026-06-07 10:35:29,753, data_manager.py, 161, INFO, Processing year 2015 for ticker PFMT.
# 2026-06-07 10:35:29,770, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PFMT\PFMT_2015
# 2026-06-07 10:35:29,793, data_manager.py, 161, INFO, Processing year 2016 for ticker PFMT.
# 2026-06-07 10:35:29,805, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PFMT\PFMT_2016
# 2026-06-07 10:35:29,830, data_manager.py, 161, INFO, Processing year 2017 for ticker PFMT.
# 2026-06-07 10:35:29,835, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PFMT\PFMT_2017
# 2026-06-07 10:35:29,858, data_manager.py, 161, INFO, Processing year 2018 for ticker PFMT.
# 2026-06-07 10:35:29,860, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PFMT\PFMT_2018
# 2026-06-07 10:35:29,888, data_manager.py, 161, INFO, Processing year 2019 for ticker PFMT.
# 2026-06-07 10:35:29,894, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PFMT\PFMT_2019
# 2026-06-07 10:35:29,903, data_manager.py, 161, INFO, Processing year 2020 for ticker PFMT.
# 2026-06-07 10:35:29,918, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/PFMT\PFMT_2020
# 2026-06-07 10:35:29,940, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\TACT.csv
# 2026-06-07 10:35:29,941, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\TACT.csv
# 2026-06-07 10:35:29,966, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:29,966, data_manager.py, 157, INFO, Processing ticker: TACT
# 2026-06-07 10:35:29,972, data_manager.py, 161, INFO, Processing year 1996 for ticker TACT.
# 2026-06-07 10:35:29,978, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_1996
# 2026-06-07 10:35:30,003, data_manager.py, 161, INFO, Processing year 1997 for ticker TACT.
# 2026-06-07 10:35:30,010, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_1997
# 2026-06-07 10:35:30,040, data_manager.py, 161, INFO, Processing year 1998 for ticker TACT.
# 2026-06-07 10:35:30,053, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_1998
# 2026-06-07 10:35:30,097, data_manager.py, 161, INFO, Processing year 1999 for ticker TACT.
# 2026-06-07 10:35:30,103, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_1999
# 2026-06-07 10:35:30,131, data_manager.py, 161, INFO, Processing year 2000 for ticker TACT.
# 2026-06-07 10:35:30,140, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_2000
# 2026-06-07 10:35:30,164, data_manager.py, 161, INFO, Processing year 2001 for ticker TACT.
# 2026-06-07 10:35:30,171, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_2001
# 2026-06-07 10:35:30,193, data_manager.py, 161, INFO, Processing year 2002 for ticker TACT.
# 2026-06-07 10:35:30,193, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_2002
# 2026-06-07 10:35:30,222, data_manager.py, 161, INFO, Processing year 2003 for ticker TACT.
# 2026-06-07 10:35:30,227, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_2003
# 2026-06-07 10:35:30,237, data_manager.py, 161, INFO, Processing year 2004 for ticker TACT.
# 2026-06-07 10:35:30,255, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_2004
# 2026-06-07 10:35:30,288, data_manager.py, 161, INFO, Processing year 2005 for ticker TACT.
# 2026-06-07 10:35:30,295, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_2005
# 2026-06-07 10:35:30,321, data_manager.py, 161, INFO, Processing year 2006 for ticker TACT.
# 2026-06-07 10:35:30,326, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_2006
# 2026-06-07 10:35:30,347, data_manager.py, 161, INFO, Processing year 2007 for ticker TACT.
# 2026-06-07 10:35:30,359, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/TACT\TACT_2007
# ...
# 2026-06-07 10:35:36,177, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2003
# 2026-06-07 10:35:36,198, data_manager.py, 161, INFO, Processing year 2004 for ticker MCBC.
# 2026-06-07 10:35:36,206, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2004
# 2026-06-07 10:35:36,228, data_manager.py, 161, INFO, Processing year 2005 for ticker MCBC.
# 2026-06-07 10:35:36,234, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2005
# 2026-06-07 10:35:36,255, data_manager.py, 161, INFO, Processing year 2006 for ticker MCBC.
# 2026-06-07 10:35:36,259, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2006
# 2026-06-07 10:35:36,289, data_manager.py, 161, INFO, Processing year 2007 for ticker MCBC.
# 2026-06-07 10:35:36,293, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2007
# 2026-06-07 10:35:36,314, data_manager.py, 161, INFO, Processing year 2008 for ticker MCBC.
# 2026-06-07 10:35:36,328, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2008
# 2026-06-07 10:35:36,338, data_manager.py, 161, INFO, Processing year 2009 for ticker MCBC.
# 2026-06-07 10:35:36,355, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2009
# 2026-06-07 10:35:36,379, data_manager.py, 161, INFO, Processing year 2010 for ticker MCBC.
# 2026-06-07 10:35:36,386, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2010
# 2026-06-07 10:35:36,410, data_manager.py, 161, INFO, Processing year 2011 for ticker MCBC.
# 2026-06-07 10:35:36,410, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2011
# 2026-06-07 10:35:36,438, data_manager.py, 161, INFO, Processing year 2012 for ticker MCBC.
# 2026-06-07 10:35:36,438, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2012
# 2026-06-07 10:35:36,464, data_manager.py, 161, INFO, Processing year 2013 for ticker MCBC.
# 2026-06-07 10:35:36,476, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2013
# 2026-06-07 10:35:36,500, data_manager.py, 161, INFO, Processing year 2014 for ticker MCBC.
# 2026-06-07 10:35:36,509, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2014
# 2026-06-07 10:35:36,526, data_manager.py, 161, INFO, Processing year 2015 for ticker MCBC.
# 2026-06-07 10:35:36,544, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2015
# 2026-06-07 10:35:36,573, data_manager.py, 161, INFO, Processing year 2016 for ticker MCBC.
# 2026-06-07 10:35:36,581, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2016
# 2026-06-07 10:35:36,609, data_manager.py, 161, INFO, Processing year 2017 for ticker MCBC.
# 2026-06-07 10:35:36,612, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2017
# 2026-06-07 10:35:36,641, data_manager.py, 161, INFO, Processing year 2018 for ticker MCBC.
# 2026-06-07 10:35:36,647, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2018
# 2026-06-07 10:35:36,655, data_manager.py, 161, INFO, Processing year 2019 for ticker MCBC.
# 2026-06-07 10:35:36,675, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2019
# 2026-06-07 10:35:36,693, data_manager.py, 161, INFO, Processing year 2020 for ticker MCBC.
# 2026-06-07 10:35:36,705, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/MCBC\MCBC_2020
# 2026-06-07 10:35:36,729, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\XPO.csv
# 2026-06-07 10:35:36,730, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\XPO.csv
# 2026-06-07 10:35:36,759, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:36,761, data_manager.py, 157, INFO, Processing ticker: XPO
# 2026-06-07 10:35:36,764, data_manager.py, 161, INFO, Processing year 2003 for ticker XPO.
# 2026-06-07 10:35:36,771, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2003
# 2026-06-07 10:35:36,795, data_manager.py, 161, INFO, Processing year 2004 for ticker XPO.
# 2026-06-07 10:35:36,800, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2004
# 2026-06-07 10:35:36,828, data_manager.py, 161, INFO, Processing year 2005 for ticker XPO.
# 2026-06-07 10:35:36,829, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2005
# 2026-06-07 10:35:36,855, data_manager.py, 161, INFO, Processing year 2006 for ticker XPO.
# 2026-06-07 10:35:36,863, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2006
# 2026-06-07 10:35:36,878, data_manager.py, 161, INFO, Processing year 2007 for ticker XPO.
# 2026-06-07 10:35:36,893, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2007
# 2026-06-07 10:35:36,913, data_manager.py, 161, INFO, Processing year 2008 for ticker XPO.
# 2026-06-07 10:35:36,919, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2008
# 2026-06-07 10:35:36,944, data_manager.py, 161, INFO, Processing year 2009 for ticker XPO.
# 2026-06-07 10:35:36,946, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2009
# 2026-06-07 10:35:36,978, data_manager.py, 161, INFO, Processing year 2010 for ticker XPO.
# 2026-06-07 10:35:36,985, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2010
# 2026-06-07 10:35:37,015, data_manager.py, 161, INFO, Processing year 2011 for ticker XPO.
# 2026-06-07 10:35:37,022, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2011
# 2026-06-07 10:35:37,069, data_manager.py, 161, INFO, Processing year 2012 for ticker XPO.
# 2026-06-07 10:35:37,081, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2012
# 2026-06-07 10:35:37,109, data_manager.py, 161, INFO, Processing year 2013 for ticker XPO.
# 2026-06-07 10:35:37,128, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2013
# 2026-06-07 10:35:37,165, data_manager.py, 161, INFO, Processing year 2014 for ticker XPO.
# 2026-06-07 10:35:37,176, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2014
# 2026-06-07 10:35:37,223, data_manager.py, 161, INFO, Processing year 2015 for ticker XPO.
# 2026-06-07 10:35:37,231, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2015
# 2026-06-07 10:35:37,261, data_manager.py, 161, INFO, Processing year 2016 for ticker XPO.
# 2026-06-07 10:35:37,266, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2016
# 2026-06-07 10:35:37,296, data_manager.py, 161, INFO, Processing year 2017 for ticker XPO.
# 2026-06-07 10:35:37,308, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2017
# 2026-06-07 10:35:37,328, data_manager.py, 161, INFO, Processing year 2018 for ticker XPO.
# 2026-06-07 10:35:37,344, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2018
# 2026-06-07 10:35:37,371, data_manager.py, 161, INFO, Processing year 2019 for ticker XPO.
# 2026-06-07 10:35:37,390, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2019
# 2026-06-07 10:35:37,426, data_manager.py, 161, INFO, Processing year 2020 for ticker XPO.
# 2026-06-07 10:35:37,433, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/XPO\XPO_2020
# 2026-06-07 10:35:37,461, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\SOHU.csv
# 2026-06-07 10:35:37,463, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\SOHU.csv
# 2026-06-07 10:35:37,501, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:37,503, data_manager.py, 157, INFO, Processing ticker: SOHU
# 2026-06-07 10:35:37,507, data_manager.py, 161, INFO, Processing year 2000 for ticker SOHU.
# 2026-06-07 10:35:37,509, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2000
# 2026-06-07 10:35:37,543, data_manager.py, 161, INFO, Processing year 2001 for ticker SOHU.
# 2026-06-07 10:35:37,552, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2001
# 2026-06-07 10:35:37,583, data_manager.py, 161, INFO, Processing year 2002 for ticker SOHU.
# 2026-06-07 10:35:37,595, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2002
# 2026-06-07 10:35:37,622, data_manager.py, 161, INFO, Processing year 2003 for ticker SOHU.
# 2026-06-07 10:35:37,631, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2003
# 2026-06-07 10:35:37,660, data_manager.py, 161, INFO, Processing year 2004 for ticker SOHU.
# 2026-06-07 10:35:37,666, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2004
# 2026-06-07 10:35:37,690, data_manager.py, 161, INFO, Processing year 2005 for ticker SOHU.
# 2026-06-07 10:35:37,696, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2005
# 2026-06-07 10:35:37,710, data_manager.py, 161, INFO, Processing year 2006 for ticker SOHU.
# 2026-06-07 10:35:37,726, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2006
# 2026-06-07 10:35:37,747, data_manager.py, 161, INFO, Processing year 2007 for ticker SOHU.
# 2026-06-07 10:35:37,758, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2007
# 2026-06-07 10:35:37,787, data_manager.py, 161, INFO, Processing year 2008 for ticker SOHU.
# 2026-06-07 10:35:37,797, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2008
# 2026-06-07 10:35:37,828, data_manager.py, 161, INFO, Processing year 2009 for ticker SOHU.
# 2026-06-07 10:35:37,835, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2009
# 2026-06-07 10:35:37,864, data_manager.py, 161, INFO, Processing year 2010 for ticker SOHU.
# 2026-06-07 10:35:37,872, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2010
# 2026-06-07 10:35:37,902, data_manager.py, 161, INFO, Processing year 2011 for ticker SOHU.
# 2026-06-07 10:35:37,910, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2011
# 2026-06-07 10:35:37,938, data_manager.py, 161, INFO, Processing year 2012 for ticker SOHU.
# 2026-06-07 10:35:37,945, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2012
# 2026-06-07 10:35:37,974, data_manager.py, 161, INFO, Processing year 2013 for ticker SOHU.
# 2026-06-07 10:35:37,982, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2013
# 2026-06-07 10:35:38,015, data_manager.py, 161, INFO, Processing year 2014 for ticker SOHU.
# 2026-06-07 10:35:38,031, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2014
# 2026-06-07 10:35:38,065, data_manager.py, 161, INFO, Processing year 2015 for ticker SOHU.
# 2026-06-07 10:35:38,065, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2015
# 2026-06-07 10:35:38,096, data_manager.py, 161, INFO, Processing year 2016 for ticker SOHU.
# 2026-06-07 10:35:38,108, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2016
# 2026-06-07 10:35:38,129, data_manager.py, 161, INFO, Processing year 2017 for ticker SOHU.
# 2026-06-07 10:35:38,138, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2017
# 2026-06-07 10:35:38,155, data_manager.py, 161, INFO, Processing year 2018 for ticker SOHU.
# 2026-06-07 10:35:38,160, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2018
# 2026-06-07 10:35:38,178, data_manager.py, 161, INFO, Processing year 2019 for ticker SOHU.
# 2026-06-07 10:35:38,192, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2019
# 2026-06-07 10:35:38,213, data_manager.py, 161, INFO, Processing year 2020 for ticker SOHU.
# 2026-06-07 10:35:38,220, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/SOHU\SOHU_2020
# 2026-06-07 10:35:38,247, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\AGBA.csv
# 2026-06-07 10:35:38,248, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\AGBA.csv
# 2026-06-07 10:35:38,270, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:38,273, data_manager.py, 157, INFO, Processing ticker: AGBA
# 2026-06-07 10:35:38,277, data_manager.py, 161, INFO, Processing year 2019 for ticker AGBA.
# 2026-06-07 10:35:38,290, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/AGBA\AGBA_2019
# 2026-06-07 10:35:38,325, data_manager.py, 161, INFO, Processing year 2020 for ticker AGBA.
# 2026-06-07 10:35:38,331, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/AGBA\AGBA_2020
# 2026-06-07 10:35:38,357, data_manager.py, 137, INFO, Processing file ../../05_src/data/prices_csv\stocks\CPIX.csv
# 2026-06-07 10:35:38,358, data_manager.py, 186, INFO, Reading file: ../../05_src/data/prices_csv\stocks\CPIX.csv
# 2026-06-07 10:35:38,378, data_manager.py, 155, INFO, Saving data by year
# 2026-06-07 10:35:38,378, data_manager.py, 157, INFO, Processing ticker: CPIX
# 2026-06-07 10:35:38,388, data_manager.py, 161, INFO, Processing year 2009 for ticker CPIX.
# 2026-06-07 10:35:38,394, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2009
# 2026-06-07 10:35:38,418, data_manager.py, 161, INFO, Processing year 2010 for ticker CPIX.
# 2026-06-07 10:35:38,425, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2010
# 2026-06-07 10:35:38,457, data_manager.py, 161, INFO, Processing year 2011 for ticker CPIX.
# 2026-06-07 10:35:38,477, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2011
# 2026-06-07 10:35:38,508, data_manager.py, 161, INFO, Processing year 2012 for ticker CPIX.
# 2026-06-07 10:35:38,515, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2012
# 2026-06-07 10:35:38,545, data_manager.py, 161, INFO, Processing year 2013 for ticker CPIX.
# 2026-06-07 10:35:38,557, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2013
# 2026-06-07 10:35:38,595, data_manager.py, 161, INFO, Processing year 2014 for ticker CPIX.
# 2026-06-07 10:35:38,605, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2014
# 2026-06-07 10:35:38,643, data_manager.py, 161, INFO, Processing year 2015 for ticker CPIX.
# 2026-06-07 10:35:38,650, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2015
# 2026-06-07 10:35:38,678, data_manager.py, 161, INFO, Processing year 2016 for ticker CPIX.
# 2026-06-07 10:35:38,679, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2016
# 2026-06-07 10:35:38,710, data_manager.py, 161, INFO, Processing year 2017 for ticker CPIX.
# 2026-06-07 10:35:38,717, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2017
# 2026-06-07 10:35:38,744, data_manager.py, 161, INFO, Processing year 2018 for ticker CPIX.
# 2026-06-07 10:35:38,751, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2018
# 2026-06-07 10:35:38,783, data_manager.py, 161, INFO, Processing year 2019 for ticker CPIX.
# 2026-06-07 10:35:38,792, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2019
# 2026-06-07 10:35:38,825, data_manager.py, 161, INFO, Processing year 2020 for ticker CPIX.
# 2026-06-07 10:35:38,832, data_manager.py, 165, INFO, Writing data to path: ../../05_src/data/prices/CPIX\CPIX_2020

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2026-06-07 10:35:40,791, data_manager.py, 200, INFO, Creating features data.
# 2026-06-07 10:35:40,792, data_manager.py, 207, INFO, Loading price data from ../../05_src/data/prices/
# 2026-06-07 10:35:41,653, data_manager.py, 244, INFO, Saving features to ../../05_src/data/features/stock_features
